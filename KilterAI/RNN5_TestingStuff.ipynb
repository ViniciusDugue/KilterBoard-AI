# %%
# %pip uninstall boardlib
# %pip install boardlib
# %pip install pandas
# %pip install pandasgui
# Download the kilter dataset by running this in the terminal:
# boardlib database kilter ./kilter.db
# Out:
# Requirement already satisfied: boardlib in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (0.5.2)
# Requirement already satisfied: bs4 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from boardlib) (0.0.2)
# Requirement already satisfied: requests in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from boardlib) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from bs4->boardlib) (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from requests->boardlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from requests->boardlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from requests->boardlib) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from requests->boardlib) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\viniciusdugue\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->bs4->boardlib) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlite3
import boardlib
import pandas as pd
from pandasgui import show
import matplotlib.pyplot as plt
import scipy.sparse as sp
import numpy as np

from PIL import Image, ImageDraw

from process import map_vgrade, id_to_index, id_to_coordinate, frame_to_ids, frame_to_triplets, triplets_to_matrix, frame_to_sparse_matrix, is_frame_valid, filter_frame, filter_climbs, sort_frame, filtered_df_to_text_file
from visualize import analyze_starting_hold_heights, plot_vgrade_counts, plot_hold_counts, print_unique_climbs_count, count_unique_words, draw_colored_circles_on_image, frame_to_imagecoords, frame_to_image
from markov import Markov, predict_valid_sequence
import embeddings as emb
from embeddings import hold_directions2, hold_directions, hold_magnitudes
import torch
from torch.utils.data import Dataset
# Out:
# [14. 14.]
# [[-0.76 -0.65]
#  [ 0.68 -0.74]]
# [0.8]

# %% [markdown]
# ### Creating SQL Database Connection and Converting tables to dfs ###

# %%
con = sqlite3.connect('kilter.db')
cur = con.cursor()
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
table_names = [entry[0] for entry in table_list]
table_names.sort()
print(table_names)
con.close()

def table_to_df(table_name):
    con = sqlite3.connect('kilter.db')

    df =  pd.read_sql_query(f"SELECT * FROM {table_name}", con)
    
    con.close()

    return df

# get all tables as dfs
for table_name in table_names:
    globals()[table_name] = table_to_df(table_name)
# print("The available dataframes are: \n\t" + "\n\t".join(table_names))
# Out:
# ['android_metadata', 'ascents', 'attempts', 'beta_links', 'bids', 'circuits', 'circuits_climbs', 'climb_cache_fields', 'climb_random_positions', 'climb_stats', 'climbs', 'difficulty_grades', 'holes', 'kits', 'layouts', 'leds', 'placement_roles', 'placements', 'product_sizes', 'product_sizes_layouts_sets', 'products', 'products_angles', 'sets', 'shared_syncs', 'tags', 'user_permissions', 'user_syncs', 'users', 'walls', 'walls_sets']

# %% [markdown]
# ### Create Filtered DF with Merged Tables

# %%
# print(globals()['ascents'].head().to_string(index=False)) #for printing head of table

def merge_filter_climbs(climbs, climb_stats):
    merged_df = pd.merge(climbs, climb_stats, left_on='uuid', right_on='climb_uuid', how='inner')
    merged_df = merged_df[merged_df['layout_id'] == 1]
    
    # Remove rows with 2 or less ascensionists
    merged_df = merged_df[merged_df['ascensionist_count'] >= 1]  # about 101629 climbs

    merged_df['vgrade'] = merged_df['display_difficulty'].apply(map_vgrade)

    filtered_columns = ['name','vgrade','angle_y','display_difficulty','created_at', 'ascensionist_count','frames','fa_username', 'benchmark_difficulty',  'is_draft',  'climb_uuid']
    filtered_df = merged_df.loc[:, filtered_columns]
    
    filtered_df = filtered_df.drop_duplicates(subset=['name'])
    
    filtered_df['hold_count'] = filtered_df['frames'].str.count('p')

    filtered_df = filtered_df[filtered_df['hold_count'] <=21] # 21 is about 100649 climbs
    return filtered_df

climbs = globals()['climbs']
climb_stats=globals()['climb_stats']
filtered_df = merge_filter_climbs(climbs, climb_stats)

# print("Number of climbs:", filtered_df.shape[0])

# %% [markdown]
# ### Some Graphs

# %%
# plot_vgrade_counts(filtered_df)
# plot_hold_counts(filtered_df)
# average_starting_hold_height, percentage_with_starting_holds_at_35 = analyze_starting_hold_heights(filtered_df)
# print_unique_climbs_count(filtered_df)

# %% [markdown]
# ### Create Text File

# %%
filtered_df = filter_climbs(filtered_df, vgrade=-1, angle=-1)
filtered_df['frames'] = filtered_df['frames'].apply(sort_frame)
filtered_df_to_text_file(filtered_df, file_path='climbs.txt')



file_path = 'climbs.txt'

# def print_unique_words(file_path):
#     word_counts = count_unique_words(file_path)
#     if word_counts:
#         sorted_word_counts = sorted(word_counts.items(), key=lambda item: item[0], reverse=True)
#         for word, count in sorted_word_counts:
#             print(word, count)

# %%
# frame = "p1476r15p1152r12p1172r12p1504r15p1200r13p1230r13p1252r13p1319r13p1335r13p1387r14p1165r15p1511r15p1216r13"
# frame_to_image(frame)

# %% [markdown]
# ### Markov Chain Model

# %%
m = Markov(file_path='climbs.txt')
chain = m.model

valid_sequence = predict_valid_sequence(chain, '1476r15', number_of_words=13)
def frame_to_image(frame):
    image_path = "KilterBoardSetup.png"
    coords_list = frame_to_imagecoords(frame)
    print(coords_list)
    draw_colored_circles_on_image(image_path, coords_list)
print("Valid Sequence:", valid_sequence)
generated_frame = 'p' + valid_sequence.replace(' ', 'p')
frame_to_image(generated_frame)

# r12 - starthold  
# r13 - hand hold  
# r14 - finish hold 
# r15 - foot hold
# Out:
# Successfully Trained
# Valid Sequence: 1476r15 1147r12 1163r15 1186r13 1191r13 1239r13 1551r15 1268r13 1320r13 1358r13 1395r14 1101r15 1111r12
# [(236, 847.0, 5), (297, 784, 2), (255, 742, 5), (507, 700, 3), (717, 700, 3), (591, 574, 3), (494, 503.0, 5), (381, 490, 3), (423, 364, 3), (591, 280, 3), (717, 196, 4), (507, 910, 5), (213, 868, 2)]

# %%
def ids_to_coordinates():
    # Iterate through the first range: 1073-1395
    for id in range(1073, 1396):
        coord = id_to_coordinate(id)
        # print(f"ID {id} converted to coordinates: {coord}")
    
    # Iterate through the second range: 1447-1599
    for id in range(1447, 1600):
        coord = id_to_coordinate(id)
        # print(f"ID {id} converted to coordinates: {coord}")

ids_to_coordinates()

# %% [markdown]
# ### Prepare Data into npz file ###

# %%
def get_hold_vector(row, col):
    if not isinstance(row, int):
        raise TypeError(f"Row index must be an integer, got {type(row)} row: {row}")
    if not isinstance(col, int):
        raise TypeError(f"Column index must be an integer, got {type(col)} col: {col}")
    
    if row > 34 or col > 34:
        if row > col:
            raise ValueError(f"Row index {row} exceeds maximum allowed value of 34.")
        else:
            raise ValueError(f"Column index {col} exceeds maximum allowed value of 34.")
    
    if max(hold_directions[34 - row][col]) > 1:
        index = int(hold_directions[34 - row][col][0]) - 1
        hold_direction = hold_directions2[index].tolist()
    else:
        hold_direction = hold_directions[34 - row][col].tolist()
    
    hold_magnitude = hold_magnitudes[34 - row][col][0]
    
    return hold_direction, hold_magnitude

# hold_direction, hold_magnitude = get_hold_vector(row, col)

def unit_vector_to_sin(vector):
    x, y = vector
    angle_radians = np.arctan2(y, x)
    sin_value = np.sin(angle_radians)
    return sin_value

def unit_vector_to_cos(vector):
    x, y = vector
    angle_radians = np.arctan2(y, x)
    cos_value = np.cos(angle_radians)
    return cos_value

def modified_hold_quality(climb_angle, hold_quality):
    if isinstance(climb_angle, torch.Tensor):
        climb_angle_cpu = climb_angle.cpu().numpy()
    else:
        climb_angle_cpu = np.array(climb_angle)
    climb_angle_radians = np.deg2rad(climb_angle_cpu)
    modified_quality = np.cos(climb_angle_radians * hold_quality)
    return modified_quality

def interhold_angle(a, b):
    x1, y1 = a
    x2, y2 = b
    angle_radians = np.arctan2(y2 - y1, x2 - x1)
    return angle_radians

def average_unit_vectors(vectors):
    if len(vectors) == 1:
        return vectors[0]
    elif len(vectors) == 2:
        avg_x = (vectors[0][0] + vectors[1][0]) / 2
        avg_y = (vectors[0][1] + vectors[1][1]) / 2
        norm = np.sqrt(avg_x**2 + avg_y**2)
        return [avg_x / norm, avg_y / norm]
    else:
        raise ValueError("The input should be a list containing one or two unit vectors.")

def id_to_class_id(id):
    if id <=1089: # 0-16
        class_id = id - 1073 
    elif id <=1395: # 17-322
        class_id = id - 1090 + 17
    elif id <= 1464: # 323-340
        class_id = id - 1447 + 323
    elif id <= 1599: # 341-475
        class_id = id - 1465 + 341
    return class_id

def class_id_to_id(class_id):
    if class_id <= 16:  # 0-16
        id = class_id + 1073
    elif class_id <= 322:  # 17-322
        id = class_id + 1090 - 17
    elif class_id <= 340:  # 323-340
        id = class_id + 1447 - 323
    elif class_id <= 475:  # 341-475
        id = class_id + 1465 - 341 
    return id

def ids_to_hold_val_class_id(hold_class_id, val_class_id):
    hold_val_class_id = (hold_class_id) * 4 + val_class_id
    return hold_val_class_id

def hold_val_class_id_to_ids(hold_val_class_id):
    val_class_id = hold_val_class_id % 4
    hold_class_id = int((hold_val_class_id - val_class_id) /4)
    return hold_class_id, val_class_id

def climb_to_tupleslist(row):
    frames = row['frames']
    climb_angle = row['angle_y']
    climb_difficulty = map_vgrade(row['display_difficulty'])

    triplets = frame_to_triplets(frames)
    hold_ids =  frame_to_ids(frames)[0]
    feature_tuples = []

    for i, (x, y, val) in enumerate(triplets):
        hold_direction, hold_quality = get_hold_vector(y, x)
        hold_class_id = id_to_class_id(hold_ids[i])
        val_class_id = val-2
        hold_val_class_id = ids_to_hold_val_class_id(hold_class_id, val_class_id)

        # Check if hold_direction is a list of lists and average if necessary
        if isinstance(hold_direction[0], list):  
            hold_direction = average_unit_vectors(hold_direction)

        hold_angle = unit_vector_to_cos(hold_direction)
        modified_quality = modified_hold_quality(climb_angle, hold_quality)
        

        if i < len(triplets) - 1:
            next_x, next_y, _ = triplets[i + 1]
            inter_hold_angle = np.sin(interhold_angle((x, y), (next_x, next_y)))
        else:
            inter_hold_angle = 0  # Last hold doesn't have a next hold
        
        feature_tuple = (y, x, val- 2 , hold_class_id, hold_val_class_id, hold_angle, hold_quality)
        
        # Validate feature_tuple elements
        for j, feature in enumerate(feature_tuple):
            if not isinstance(feature, (int, float)):
                raise ValueError(f"Invalid feature type at index {j}: {type(feature)}")
        
        feature_tuples.append(feature_tuple)
    
    return feature_tuples

def df_to_npz(df, filename, num_climbs=None, random_climbs=False):
    climb_matrices = {}

    if num_climbs is not None and num_climbs != "all":
        if random_climbs:
            df = df.sample(n=num_climbs)
        else:
            df = df.head(num_climbs)

    for idx, row in df.iterrows():
        climb_name = row['name']
        feature_tuples = climb_to_tupleslist(row)

        matrix = np.array([list(t) for t in feature_tuples])
        climb_matrices[climb_name] = matrix

    np.savez_compressed(filename, **climb_matrices)

df_to_npz(filtered_df, 'climb_matrices.npz', num_climbs=40000, random_climbs=True)


def load_npz(file):
    data = np.load(file, allow_pickle=True)
    matrices = {key: data[key] for key in data}
    return matrices

def calculate_global_stats(matrices):
    all_data = np.concatenate([matrix for matrix in matrices.values()])
    global_means = np.mean(all_data, axis=0)
    global_stds = np.std(all_data, axis=0)

    # Avoid division by zero
    global_stds[global_stds == 0] = 1

    return global_means, global_stds


def standardize_matrix(matrix, global_means, global_stds):
    standardized_matrix = np.copy(matrix)
    standardized_matrix[:, [0, 1, 5, 6]] = (matrix[:, [0, 1, 5, 6]] - global_means[[0, 1, 5, 6]]) / global_stds[[0, 1, 5, 6]]
    return standardized_matrix


def standardize_npz(input_file, output_file):
    matrices = load_npz(input_file)
    global_means, global_stds = calculate_global_stats(matrices)
    print(global_means)
    
    standardized_matrices = {}
    for climb_name, matrix in matrices.items():
        standardized_matrix = standardize_matrix(matrix, global_means, global_stds)
        standardized_matrices[climb_name] = standardized_matrix
    
    np.savez_compressed(output_file, **standardized_matrices)
    return global_means, global_stds

# Example usage:
global_means, global_stds = standardize_npz('climb_matrices.npz', 'standardized_climb_matrices.npz')

def hold_to_tuple(hold_class_id, val,):
    # Convert the hold string to triplets (it will return a list with a single triplet)
    hold_id = class_id_to_id(int(hold_class_id))
    x, y = id_to_coordinate(hold_id)

    val_class_id = val-2
    hold_val_class_id = ids_to_hold_val_class_id(hold_class_id, val_class_id)

    # Get hold direction and hold quality
    hold_direction, hold_quality = get_hold_vector(y, x)
    
    # Check if hold_direction is a list of lists and average if necessary
    if isinstance(hold_direction[0], list):
        hold_direction = average_unit_vectors(hold_direction)

    hold_angle = unit_vector_to_cos(hold_direction)
    
    feature_tuple = (y, x, val_class_id, hold_class_id, hold_val_class_id, hold_angle, hold_quality)
    
    # Validate feature_tuple elements
    for j, feature in enumerate(feature_tuple):
        if not isinstance(feature, (int, float)):
            raise ValueError(f"Invalid feature type at index {j}: {type(feature)}")
    return feature_tuple
# Out:
# [ 1.72937232e+01  1.70116963e+01  1.63153383e+00  2.25193680e+02
#   9.02406255e+02 -4.03760351e-03  5.91782634e-01]

# %% [markdown]
# ### RNN Model ###

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.utils.parametrizations as weight_norm
import torch.nn.init as init
from collections import Counter

# Check if CUDA is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class ClimbDataset(Dataset):
    def __init__(self, npz_file):
        self.data = np.load(npz_file, allow_pickle=True)
        self.climb_names = list(self.data.keys())
        self.num_climbs = len(self.climb_names)
    
    def __len__(self):
        return self.num_climbs
    
    def __getitem__(self, idx):
        climb_name = self.climb_names[idx]
        climb_matrix = self.data[climb_name]
        return climb_matrix

class RNN(nn.Module):
    def __init__(self, input_size=7, hidden_size=128, num_layers=2):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        
        # Initialize LSTM weights
        for name, param in self.rnn.named_parameters():
            if 'weight' in name:
                init.orthogonal_(param)
            elif 'bias' in name:
                init.constant_(param, 0)
        
        # Task-specific layer for hold_val_class prediction
        self.fc_hold_val_class = nn.Linear(hidden_size, 1904)  # Define the linear layer first
        
        # Initialize FC layer weights
        init.xavier_uniform_(self.fc_hold_val_class.weight)
        init.constant_(self.fc_hold_val_class.bias, 0)
        
        # Apply weight normalization using torch.nn.utils.parametrizations.weight_norm
        self.fc_hold_val_class = weight_norm.weight_norm(self.fc_hold_val_class, name='weight', dim=None)

    def forward(self, x, lengths, h0=None, c0=None):
        lengths = lengths.cpu().long()  # Ensure lengths tensor is on CPU and of type int64
        packed_input = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        
        if h0 is None:
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        if c0 is None:
            c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        packed_output, (hn, cn) = self.rnn(packed_input, (h0, c0))
        
        out, _ = pad_packed_sequence(packed_output, batch_first=True)
        
        # Get the output of the last time step
        out = out[torch.arange(out.size(0)), lengths - 1]
        
        hold_val_class_pred = self.fc_hold_val_class(out)
        
        return hold_val_class_pred, hn, cn

# Define collate function for DataLoader to handle variable-length sequences
def collate_fn(batch):
    batch.sort(key=lambda x: len(x), reverse=True)
    sequences = [torch.tensor(x, dtype=torch.float32) for x in batch]
    lengths = torch.tensor([len(x) for x in sequences])
    padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=0)
    return padded_sequences, lengths

import torch.nn.functional as F

# def custom_loss(pred_class_probabilities, padded_sequences, lengths, beta=1, top_k=5, use_l1=False):
#     batch_size = padded_sequences.size(0)
#     total_loss = 0.0
    
#     for i in range(batch_size):
#         climb_angle = padded_sequences[i, lengths[i].cpu().long() - 2, 9].item()
#         climb_difficulty = padded_sequences[i, lengths[i].cpu().long() - 2, 10].item()

        
#         # Sort and select top-K predicted class probabilities
#         values, top_k_indices = torch.topk(pred_class_probabilities[i], k=top_k)
        
#         for j in range(top_k):
#             pred_class_id = top_k_indices[j]
#             pred_hold_id, pred_val_id = hold_val_class_id_to_ids(pred_class_id.item())
            
#             pred_tuple = hold_to_tuple(pred_hold_id, pred_val_id, climb_angle, climb_difficulty)
#             expected_class_id = padded_sequences[i, lengths[i].cpu().long() - 1, 4].long().item()  # Extract target hold_val_class
#             expected_hold_id, expected_val_id = hold_val_class_id_to_ids(expected_class_id)
#             expected_tuple = hold_to_tuple(expected_hold_id, expected_val_id, climb_angle, climb_difficulty)
            
#             pred_tuple_values = torch.tensor((pred_tuple[0], pred_tuple[1], pred_tuple[5], pred_tuple[6], pred_tuple[7]))# row, col, hold angle, hold quality, modified hold quality
#             expected_tuple_values = torch.tensor((expected_tuple[0], expected_tuple[1], expected_tuple[5], expected_tuple[6], expected_tuple[7]))
            
#             # Calculate losses for other tuple values (e.g., using L1 or L2 loss)
#             if use_l1:
#                 loss_other_values = F.l1_loss(pred_tuple_values, expected_tuple_values, reduction='sum')
#             else:
#                 loss_other_values = F.mse_loss(pred_tuple_values, expected_tuple_values, reduction='sum')
            
#             # Weighted sum or combination of losses
#             total_loss += beta * loss_other_values.sum()

#     # Average loss over top-K predictions and batch size
#     total_loss /= (top_k * batch_size)
    
#     return total_loss

# Load your dataset
dataset = ClimbDataset('standardized_climb_matrices.npz')

# Calculate split sizes
total_size = len(dataset)
test_size = int(0.1 * total_size)  # 10% for test
remaining_size = total_size - test_size
train_size = int(0.7 * total_size)  # 70% of total for training (which is 70/90 of remaining)
val_size = remaining_size - train_size  # The remaining 20% of total for validation

# Split dataset into train, validation, and test sets
train_val_dataset, test_dataset = random_split(dataset, [remaining_size, test_size])
train_dataset, val_dataset = random_split(train_val_dataset, [train_size, val_size])

# Create DataLoaders with collate_fn
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)

def calculate_class_weights(dataset, scale_factor=1.0):
    class_counts = Counter()
    
    # Calculate class frequencies
    for padded_sequences, lengths in DataLoader(dataset, batch_size=1, collate_fn=collate_fn):
        hold_val_classes = padded_sequences[torch.arange(padded_sequences.size(0)), lengths - 1, 4].long()
        class_counts.update(hold_val_classes.cpu().numpy())
    
    # Total number of samples
    total_samples = sum(class_counts.values())

    # Calculate class weights based on inverse frequency with scaling factor
    class_weights = {cls: scale_factor * total_samples / (count * len(class_counts)) for cls, count in class_counts.items()}
    
    return class_weights


# Calculate class weights with a scale factor (e.g., 0.5 for half the original weight)
class_weights = calculate_class_weights(train_dataset, scale_factor=300)

# Calculate max class index
max_cls_index = max(class_weights.keys())

# Initialize weight tensor with appropriate size
weight_tensor = torch.zeros(max_cls_index + 1)

# Assign weights to corresponding indices
for cls, weight in class_weights.items():
    weight_tensor[cls] = weight

# Move the weight tensor to GPU if available
weight_tensor = weight_tensor.to(device)

print(weight_tensor.size())
# # Initialize the model and move it to GPU if available
model = RNN().to(device)

# Define loss functions
criterion_hold_val_class = nn.CrossEntropyLoss(weight=weight_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.001)

beta = 0.5  # Adjust beta as needed for the custom loss
top_k = 50  # Top-k predictions to consider in custom loss

# Number of epochs
num_epochs = 15

# Lists to store loss and accuracy values
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    correct_train_preds = 0
    total_train_preds = 0
    
    # Iterate over data
    for padded_sequences, lengths in train_loader:
        padded_sequences = padded_sequences.to(device)  # Move data to GPU if available
        lengths = lengths.to(device)

        optimizer.zero_grad()  # Reset gradients for the new batch

        # Forward pass
        hold_val_class_pred, h0, c0 = model(padded_sequences, lengths)
        
        # Compute hold_val_class loss
        next_tuple_hold_val_class = padded_sequences[torch.arange(padded_sequences.size(0)), lengths.cpu().long() - 1, 4].long()  # Extract target hold_val_class
        loss_hold_val_class = criterion_hold_val_class(hold_val_class_pred, next_tuple_hold_val_class)
        
        # Compute custom loss for other tuple values
        # pred_class_probabilities = F.softmax(hold_val_class_pred, dim=1)
        # loss_custom = custom_loss(pred_class_probabilities, padded_sequences, lengths, beta=beta, top_k=top_k)
        
        # Total loss
        # batch_loss = loss_hold_val_class + loss_custom
        batch_loss = loss_hold_val_class
        # Backward pass and optimize
        batch_loss.backward()
        optimizer.step()

        running_train_loss += batch_loss.item()
        
        # Calculate training accuracy
        correct_train_preds += (torch.argmax(hold_val_class_pred, dim=1) == next_tuple_hold_val_class).sum().item()
        total_train_preds += next_tuple_hold_val_class.size(0)
    
    # Compute average training loss and accuracy
    avg_train_loss = running_train_loss / len(train_loader)
    train_accuracy = correct_train_preds / total_train_preds
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)

    # Validation loop
    model.eval()
    running_val_loss = 0.0
    correct_val_preds = 0
    total_val_preds = 0
    with torch.no_grad():
        for padded_sequences, lengths in val_loader:
            padded_sequences = padded_sequences.to(device)  # Move data to GPU if available
            lengths = lengths.to(device)

            # Forward pass
            hold_val_class_pred, h0, c0 = model(padded_sequences, lengths)

            # Compute hold_val_class loss
            next_tuple_hold_val_class = padded_sequences[torch.arange(padded_sequences.size(0)), lengths.cpu().long() - 1, 4].long()  # Extract target hold_val_class
            loss_hold_val_class = criterion_hold_val_class(hold_val_class_pred, next_tuple_hold_val_class)

            # Compute custom loss for other tuple values
            # pred_class_probabilities = F.softmax(hold_val_class_pred, dim=1)
            # loss_custom = custom_loss(pred_class_probabilities, padded_sequences, lengths, beta=beta, top_k=top_k)

            # Total loss
            # batch_loss = loss_hold_val_class + loss_custom
            batch_loss = loss_hold_val_class
            running_val_loss += batch_loss.item()

            # Calculate validation accuracy
            correct_val_preds += (torch.argmax(hold_val_class_pred, dim=1) == next_tuple_hold_val_class).sum().item()
            total_val_preds += next_tuple_hold_val_class.size(0)

    # Compute average validation loss and accuracy
    avg_val_loss = running_val_loss / len(val_loader)
    val_accuracy = correct_val_preds / total_val_preds
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)

    # Print statistics
    print(f'Epoch {epoch + 1}, Training Loss: {avg_train_loss}, Validation Loss: {avg_val_loss}, Training Accuracy: {train_accuracy}, Validation Accuracy: {val_accuracy}')

print('Finished Training')

# Plot training and validation losses
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(8, 6))
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# Evaluate the model on the test set
model.eval()
running_test_loss = 0.0
correct_test_preds = 0
total_test_preds = 0

with torch.no_grad():
    for padded_sequences, lengths in test_loader:
        padded_sequences = padded_sequences.to(device)  # Move data to GPU if available
        lengths = lengths.to(device)

        # Forward pass
        hold_val_class_pred, h0, c0 = model(padded_sequences, lengths)

        # Compute hold_val_class loss
        next_tuple_hold_val_class = padded_sequences[torch.arange(padded_sequences.size(0)), lengths.cpu().long() - 1, 4].long()  # Extract target hold_val_class
        loss_hold_val_class = criterion_hold_val_class(hold_val_class_pred, next_tuple_hold_val_class)

        # Compute custom loss for other tuple values
        # pred_class_probabilities = F.softmax(hold_val_class_pred, dim=1)
        # loss_custom = custom_loss(pred_class_probabilities, padded_sequences, lengths, beta=beta, top_k=top_k)

        # Total loss
        # batch_loss = loss_hold_val_class + loss_custom
        batch_loss = loss_hold_val_class
        running_test_loss += batch_loss.item()

        # Calculate test accuracy
        correct_test_preds += (torch.argmax(hold_val_class_pred, dim=1) == next_tuple_hold_val_class).sum().item()
        total_test_preds += next_tuple_hold_val_class.size(0)

# Compute average test loss and accuracy
avg_test_loss = running_test_loss / len(test_loader)
test_accuracy = correct_test_preds / total_test_preds

print(f'Test Loss: {avg_test_loss}, Test Accuracy: {test_accuracy}')
# Out:
# torch.Size([1904])
# Epoch 1, Training Loss: 3.8963715152740477, Validation Loss: 3.740210852622986, Training Accuracy: 0.10453571428571429, Validation Accuracy: 0.110125
# Epoch 2, Training Loss: 3.577746056692941, Validation Loss: 2.863250343322754, Training Accuracy: 0.12242857142857143, Validation Accuracy: 0.210875
# Epoch 3, Training Loss: 2.577014497075762, Validation Loss: 2.320470833301544, Training Accuracy: 0.27735714285714286, Validation Accuracy: 0.342125
# Epoch 4, Training Loss: 2.21089843245915, Validation Loss: 1.989024085521698, Training Accuracy: 0.36657142857142855, Validation Accuracy: 0.429125
# Epoch 5, Training Loss: 1.8501863549096245, Validation Loss: 1.6122257568836211, Training Accuracy: 0.5119285714285714, Validation Accuracy: 0.51425
# Epoch 6, Training Loss: 1.4007399952411652, Validation Loss: 1.1618792595863343, Training Accuracy: 0.703, Validation Accuracy: 0.763375
# Epoch 7, Training Loss: 1.1692734127385276, Validation Loss: 0.9955316053628922, Training Accuracy: 0.7590714285714286, Validation Accuracy: 0.77375
# Epoch 8, Training Loss: 1.0198633229391916, Validation Loss: 0.9851901941299438, Training Accuracy: 0.7928928571428572, Validation Accuracy: 0.75625
# Epoch 9, Training Loss: 0.9007393080507006, Validation Loss: 0.8640685437917709, Training Accuracy: 0.8204642857142858, Validation Accuracy: 0.812375
# Epoch 10, Training Loss: 0.8230216504505703, Validation Loss: 0.7178299538493157, Training Accuracy: 0.8363214285714285, Validation Accuracy: 0.869625
# Epoch 11, Training Loss: 0.746639310172626, Validation Loss: 0.6119271879792213, Training Accuracy: 0.8525, Validation Accuracy: 0.88825
# Epoch 12, Training Loss: 0.6733912697349276, Validation Loss: 0.5687337875068188, Training Accuracy: 0.8726428571428572, Validation Accuracy: 0.8795
# Epoch 13, Training Loss: 0.6339289194515774, Validation Loss: 0.5255472667515277, Training Accuracy: 0.8745357142857143, Validation Accuracy: 0.88675
# Epoch 14, Training Loss: 0.590100239608969, Validation Loss: 0.5139550518989563, Training Accuracy: 0.8838214285714285, Validation Accuracy: 0.89025
# Epoch 15, Training Loss: 0.5953082754867417, Validation Loss: 0.4914888260364533, Training Accuracy: 0.87925, Validation Accuracy: 0.893125
# Finished Training
# Test Loss: 0.5374288220405579, Test Accuracy: 0.88

# %%
import matplotlib.pyplot as plt
from collections import Counter
from torch.utils.data import DataLoader

# Example function to calculate class frequencies excluding padding
def calculate_class_frequencies(dataset, padding_value=-1):
    class_counts = Counter()
    
    # Calculate class frequencies
    for padded_sequences, lengths in DataLoader(dataset, batch_size=1, collate_fn=collate_fn):
        hold_val_classes = padded_sequences[:, :, 4].long().cpu().numpy().flatten()
        valid_indices = hold_val_classes != padding_value  # Exclude padding values
        class_counts.update(hold_val_classes[valid_indices])
    
    return class_counts

# Example dataset and calculation
class_counts = calculate_class_frequencies(train_dataset)

# Sort class indices by frequency in descending order
sorted_class_counts = dict(sorted(class_counts.items(), key=lambda item: item[1], reverse=True))
class_indices = list(sorted_class_counts.keys())
frequencies = list(sorted_class_counts.values())

# Print each class index with its frequency
for idx, freq in zip(class_indices, frequencies):
    hold_class_id, val_id = hold_val_class_id_to_ids(idx)
    print(f"Class index: {idx}, Frequency: {freq}\nHold id and Val: {class_id_to_id(hold_class_id)}, {val_id}")

# Plotting the frequencies
plt.figure(figsize=(12, 6))
plt.bar(class_indices, frequencies, color='blue')
plt.xlabel('Class Index')
plt.ylabel('Frequency')
plt.title('Frequency of Class Indices (Descending Order)')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Calculate the total sum of frequencies
total_frequency = sum(class_counts.values())
padding_value = 0
# Verify total number of holds in the dataset, excluding padding
total_instances = sum(((batch[0]- 0) != padding_value).sum().item() for batch in DataLoader(train_dataset, batch_size=1, collate_fn=collate_fn))

# Print the total sum of frequencies and total number of holds
print(f"Total sum of frequencies: {total_frequency}")
print(f"Total number of holds in the dataset: {total_instances}")

# Verify if all holds are counted
if total_frequency == total_instances:
    print("All holds are correctly counted.")
else:
    print("There is a discrepancy in the hold count.")
# Out:
# Class index: 1258, Frequency: 3403
# Hold id and Val: 1387, 2
# Class index: 917, Frequency: 2020
# Hold id and Val: 1302, 1
# Class index: 989, Frequency: 1941
# Hold id and Val: 1320, 1
# Class index: 1242, Frequency: 1882
# Hold id and Val: 1383, 2
# Class index: 645, Frequency: 1872
# Hold id and Val: 1234, 1
# Class index: 1250, Frequency: 1863
# Hold id and Val: 1385, 2
# Class index: 1274, Frequency: 1850
# Hold id and Val: 1391, 2
# Class index: 1121, Frequency: 1805
# Hold id and Val: 1353, 1
# Class index: 304, Frequency: 1796
# Hold id and Val: 1149, 0
# Class index: 1266, Frequency: 1792
# Hold id and Val: 1389, 2
# Class index: 857, Frequency: 1733
# Hold id and Val: 1287, 1
# Class index: 785, Frequency: 1721
# Hold id and Val: 1269, 1
# Class index: 725, Frequency: 1676
# Hold id and Val: 1254, 1
# Class index: 709, Frequency: 1667
# Hold id and Val: 1250, 1
# Class index: 845, Frequency: 1662
# Hold id and Val: 1284, 1
# Class index: 841, Frequency: 1657
# Hold id and Val: 1283, 1
# Class index: 1327, Frequency: 1623
# Hold id and Val: 1455, 3
# Class index: 925, Frequency: 1617
# Hold id and Val: 1304, 1
# Class index: 1278, Frequency: 1597
# Hold id and Val: 1392, 2
# Class index: 1335, Frequency: 1584
# Hold id and Val: 1457, 3
# Class index: 653, Frequency: 1580
# Hold id and Val: 1236, 1
# Class index: 1331, Frequency: 1549
# Hold id and Val: 1456, 3
# Class index: 1069, Frequency: 1535
# Hold id and Val: 1340, 1
# Class index: 1343, Frequency: 1527
# Hold id and Val: 1459, 3
# Class index: 1323, Frequency: 1513
# Hold id and Val: 1454, 3
# Class index: 1270, Frequency: 1512
# Hold id and Val: 1390, 2
# Class index: 1117, Frequency: 1507
# Hold id and Val: 1352, 1
# Class index: 1238, Frequency: 1484
# Hold id and Val: 1382, 2
# Class index: 1262, Frequency: 1478
# Hold id and Val: 1388, 2
# Class index: 1065, Frequency: 1471
# Hold id and Val: 1339, 1
# Class index: 649, Frequency: 1452
# Hold id and Val: 1235, 1
# Class index: 1254, Frequency: 1402
# Hold id and Val: 1386, 2
# Class index: 789, Frequency: 1399
# Hold id and Val: 1270, 1
# Class index: 793, Frequency: 1380
# Hold id and Val: 1271, 1
# Class index: 641, Frequency: 1372
# Hold id and Val: 1233, 1
# Class index: 1339, Frequency: 1365
# Hold id and Val: 1458, 3
# Class index: 1315, Frequency: 1355
# Hold id and Val: 1452, 3
# Class index: 981, Frequency: 1352
# Hold id and Val: 1318, 1
# Class index: 1246, Frequency: 1346
# Hold id and Val: 1384, 2
# Class index: 1295, Frequency: 1343
# Hold id and Val: 1447, 3
# Class index: 909, Frequency: 1338
# Hold id and Val: 1300, 1
# Class index: 849, Frequency: 1333
# Hold id and Val: 1285, 1
# Class index: 777, Frequency: 1298
# Hold id and Val: 1267, 1
# Class index: 360, Frequency: 1284
# Hold id and Val: 1163, 0
# Class index: 1531, Frequency: 1284
# Hold id and Val: 1506, 3
# Class index: 1363, Frequency: 1280
# Hold id and Val: 1464, 3
# Class index: 781, Frequency: 1265
# Hold id and Val: 1268, 1
# Class index: 573, Frequency: 1242
# Hold id and Val: 1216, 1
# Class index: 1286, Frequency: 1237
# Hold id and Val: 1394, 2
# Class index: 569, Frequency: 1227
# Hold id and Val: 1215, 1
# Class index: 629, Frequency: 1214
# Hold id and Val: 1230, 1
# Class index: 913, Frequency: 1212
# Hold id and Val: 1301, 1
# Class index: 933, Frequency: 1181
# Hold id and Val: 1306, 1
# Class index: 1045, Frequency: 1177
# Hold id and Val: 1334, 1
# Class index: 997, Frequency: 1177
# Hold id and Val: 1322, 1
# Class index: 1347, Frequency: 1174
# Hold id and Val: 1460, 3
# Class index: 853, Frequency: 1170
# Hold id and Val: 1286, 1
# Class index: 35, Frequency: 1161
# Hold id and Val: 1081, 3
# Class index: 1319, Frequency: 1159
# Hold id and Val: 1453, 3
# Class index: 1226, Frequency: 1149
# Hold id and Val: 1379, 2
# Class index: 1351, Frequency: 1130
# Hold id and Val: 1461, 3
# Class index: 1311, Frequency: 1129
# Hold id and Val: 1451, 3
# Class index: 773, Frequency: 1117
# Hold id and Val: 1266, 1
# Class index: 296, Frequency: 1109
# Hold id and Val: 1147, 0
# Class index: 1523, Frequency: 1103
# Hold id and Val: 1504, 3
# Class index: 509, Frequency: 1103
# Hold id and Val: 1200, 1
# Class index: 1282, Frequency: 1099
# Hold id and Val: 1393, 2
# Class index: 1049, Frequency: 1099
# Hold id and Val: 1335, 1
# Class index: 501, Frequency: 1081
# Hold id and Val: 1198, 1
# Class index: 985, Frequency: 1072
# Hold id and Val: 1319, 1
# Class index: 833, Frequency: 1050
# Hold id and Val: 1281, 1
# Class index: 372, Frequency: 1047
# Hold id and Val: 1166, 0
# Class index: 705, Frequency: 1045
# Hold id and Val: 1249, 1
# Class index: 633, Frequency: 1040
# Hold id and Val: 1231, 1
# Class index: 637, Frequency: 1036
# Hold id and Val: 1232, 1
# Class index: 1290, Frequency: 1026
# Hold id and Val: 1395, 2
# Class index: 701, Frequency: 1018
# Hold id and Val: 1248, 1
# Class index: 697, Frequency: 1009
# Hold id and Val: 1247, 1
# Class index: 1455, Frequency: 1007
# Hold id and Val: 1487, 3
# Class index: 513, Frequency: 994
# Hold id and Val: 1201, 1
# Class index: 1053, Frequency: 992
# Hold id and Val: 1336, 1
# Class index: 1559, Frequency: 985
# Hold id and Val: 1513, 3
# Class index: 969, Frequency: 984
# Hold id and Val: 1315, 1
# Class index: 1193, Frequency: 977
# Hold id and Val: 1371, 1
# Class index: 1137, Frequency: 954
# Hold id and Val: 1357, 1
# Class index: 905, Frequency: 944
# Hold id and Val: 1299, 1
# Class index: 95, Frequency: 940
# Hold id and Val: 1096, 3
# Class index: 328, Frequency: 940
# Hold id and Val: 1155, 0
# Class index: 1113, Frequency: 931
# Hold id and Val: 1351, 1
# Class index: 300, Frequency: 929
# Hold id and Val: 1148, 0
# Class index: 1383, Frequency: 923
# Hold id and Val: 1469, 3
# Class index: 993, Frequency: 922
# Hold id and Val: 1321, 1
# Class index: 941, Frequency: 922
# Hold id and Val: 1308, 1
# Class index: 765, Frequency: 921
# Hold id and Val: 1264, 1
# Class index: 565, Frequency: 920
# Hold id and Val: 1214, 1
# Class index: 1037, Frequency: 914
# Hold id and Val: 1332, 1
# Class index: 1355, Frequency: 894
# Hold id and Val: 1462, 3
# Class index: 243, Frequency: 892
# Hold id and Val: 1133, 3
# Class index: 1307, Frequency: 890
# Hold id and Val: 1450, 3
# Class index: 1591, Frequency: 884
# Hold id and Val: 1521, 3
# Class index: 521, Frequency: 869
# Hold id and Val: 1203, 1
# Class index: 1563, Frequency: 868
# Hold id and Val: 1514, 3
# Class index: 384, Frequency: 868
# Hold id and Val: 1169, 0
# Class index: 797, Frequency: 863
# Hold id and Val: 1272, 1
# Class index: 1230, Frequency: 862
# Hold id and Val: 1380, 2
# Class index: 921, Frequency: 860
# Hold id and Val: 1303, 1
# Class index: 1387, Frequency: 858
# Hold id and Val: 1470, 3
# Class index: 280, Frequency: 856
# Hold id and Val: 1143, 0
# Class index: 1061, Frequency: 855
# Hold id and Val: 1338, 1
# Class index: 320, Frequency: 854
# Hold id and Val: 1153, 0
# Class index: 865, Frequency: 848
# Hold id and Val: 1289, 1
# Class index: 1631, Frequency: 842
# Hold id and Val: 1531, 3
# Class index: 721, Frequency: 836
# Hold id and Val: 1253, 1
# Class index: 216, Frequency: 834
# Hold id and Val: 1127, 0
# Class index: 235, Frequency: 833
# Hold id and Val: 1131, 3
# Class index: 977, Frequency: 832
# Hold id and Val: 1317, 1
# Class index: 929, Frequency: 832
# Hold id and Val: 1305, 1
# Class index: 1129, Frequency: 824
# Hold id and Val: 1355, 1
# Class index: 220, Frequency: 821
# Hold id and Val: 1128, 0
# Class index: 1527, Frequency: 820
# Hold id and Val: 1505, 3
# Class index: 1379, Frequency: 818
# Hold id and Val: 1468, 3
# Class index: 737, Frequency: 812
# Hold id and Val: 1257, 1
# Class index: 621, Frequency: 788
# Hold id and Val: 1228, 1
# Class index: 1057, Frequency: 783
# Hold id and Val: 1337, 1
# Class index: 1463, Frequency: 783
# Hold id and Val: 1489, 3
# Class index: 1519, Frequency: 782
# Hold id and Val: 1503, 3
# Class index: 585, Frequency: 782
# Hold id and Val: 1219, 1
# Class index: 717, Frequency: 780
# Hold id and Val: 1252, 1
# Class index: 1033, Frequency: 770
# Hold id and Val: 1331, 1
# Class index: 505, Frequency: 770
# Hold id and Val: 1199, 1
# Class index: 1635, Frequency: 768
# Hold id and Val: 1532, 3
# Class index: 276, Frequency: 765
# Hold id and Val: 1142, 0
# Class index: 769, Frequency: 762
# Hold id and Val: 1265, 1
# Class index: 1447, Frequency: 762
# Hold id and Val: 1485, 3
# Class index: 693, Frequency: 760
# Hold id and Val: 1246, 1
# Class index: 657, Frequency: 759
# Hold id and Val: 1237, 1
# Class index: 1234, Frequency: 758
# Hold id and Val: 1381, 2
# Class index: 517, Frequency: 757
# Hold id and Val: 1202, 1
# Class index: 1571, Frequency: 755
# Hold id and Val: 1516, 3
# Class index: 1125, Frequency: 755
# Hold id and Val: 1354, 1
# Class index: 55, Frequency: 750
# Hold id and Val: 1086, 3
# Class index: 801, Frequency: 745
# Hold id and Val: 1273, 1
# Class index: 1643, Frequency: 741
# Hold id and Val: 1534, 3
# Class index: 581, Frequency: 739
# Hold id and Val: 1218, 1
# Class index: 901, Frequency: 732
# Hold id and Val: 1298, 1
# Class index: 1491, Frequency: 731
# Hold id and Val: 1496, 3
# Class index: 1303, Frequency: 719
# Hold id and Val: 1449, 3
# Class index: 1109, Frequency: 719
# Hold id and Val: 1350, 1
# Class index: 244, Frequency: 718
# Hold id and Val: 1134, 0
# Class index: 1423, Frequency: 717
# Hold id and Val: 1479, 3
# Class index: 497, Frequency: 715
# Hold id and Val: 1197, 1
# Class index: 1599, Frequency: 702
# Hold id and Val: 1523, 3
# Class index: 965, Frequency: 699
# Hold id and Val: 1314, 1
# Class index: 873, Frequency: 698
# Hold id and Val: 1291, 1
# Class index: 665, Frequency: 691
# Hold id and Val: 1239, 1
# Class index: 593, Frequency: 688
# Hold id and Val: 1221, 1
# Class index: 1391, Frequency: 687
# Hold id and Val: 1471, 3
# Class index: 861, Frequency: 687
# Hold id and Val: 1288, 1
# Class index: 1419, Frequency: 684
# Hold id and Val: 1478, 3
# Class index: 1487, Frequency: 684
# Hold id and Val: 1495, 3
# Class index: 837, Frequency: 681
# Hold id and Val: 1282, 1
# Class index: 973, Frequency: 678
# Hold id and Val: 1316, 1
# Class index: 1041, Frequency: 678
# Hold id and Val: 1333, 1
# Class index: 1133, Frequency: 676
# Hold id and Val: 1356, 1
# Class index: 252, Frequency: 675
# Hold id and Val: 1136, 0
# Class index: 1607, Frequency: 674
# Hold id and Val: 1525, 3
# Class index: 1435, Frequency: 674
# Hold id and Val: 1482, 3
# Class index: 1539, Frequency: 673
# Hold id and Val: 1508, 3
# Class index: 1551, Frequency: 661
# Hold id and Val: 1511, 3
# Class index: 284, Frequency: 658
# Hold id and Val: 1144, 0
# Class index: 713, Frequency: 656
# Hold id and Val: 1251, 1
# Class index: 1675, Frequency: 655
# Hold id and Val: 1542, 3
# Class index: 288, Frequency: 653
# Hold id and Val: 1145, 0
# Class index: 1197, Frequency: 645
# Hold id and Val: 1372, 1
# Class index: 43, Frequency: 639
# Hold id and Val: 1083, 3
# Class index: 1181, Frequency: 635
# Hold id and Val: 1368, 1
# Class index: 47, Frequency: 624
# Hold id and Val: 1084, 3
# Class index: 27, Frequency: 623
# Hold id and Val: 1079, 3
# Class index: 1001, Frequency: 605
# Hold id and Val: 1323, 1
# Class index: 1459, Frequency: 605
# Hold id and Val: 1488, 3
# Class index: 1495, Frequency: 599
# Hold id and Val: 1497, 3
# Class index: 1667, Frequency: 597
# Hold id and Val: 1540, 3
# Class index: 336, Frequency: 596
# Hold id and Val: 1157, 0
# Class index: 1415, Frequency: 595
# Hold id and Val: 1477, 3
# Class index: 597, Frequency: 584
# Hold id and Val: 1222, 1
# Class index: 1097, Frequency: 583
# Hold id and Val: 1347, 1
# Class index: 1375, Frequency: 579
# Hold id and Val: 1467, 3
# Class index: 452, Frequency: 579
# Hold id and Val: 1186, 0
# Class index: 1507, Frequency: 578
# Hold id and Val: 1500, 3
# Class index: 1411, Frequency: 578
# Hold id and Val: 1476, 3
# Class index: 1651, Frequency: 571
# Hold id and Val: 1536, 3
# Class index: 1451, Frequency: 571
# Hold id and Val: 1486, 3
# Class index: 31, Frequency: 569
# Hold id and Val: 1080, 3
# Class index: 99, Frequency: 568
# Hold id and Val: 1097, 3
# Class index: 733, Frequency: 567
# Hold id and Val: 1256, 1
# Class index: 869, Frequency: 565
# Hold id and Val: 1290, 1
# Class index: 1603, Frequency: 564
# Hold id and Val: 1524, 3
# Class index: 1073, Frequency: 561
# Hold id and Val: 1341, 1
# Class index: 1535, Frequency: 560
# Hold id and Val: 1507, 3
# Class index: 316, Frequency: 559
# Hold id and Val: 1152, 0
# Class index: 1479, Frequency: 559
# Hold id and Val: 1493, 3
# Class index: 1499, Frequency: 554
# Hold id and Val: 1498, 3
# Class index: 163, Frequency: 554
# Hold id and Val: 1113, 3
# Class index: 500, Frequency: 552
# Hold id and Val: 1198, 0
# Class index: 761, Frequency: 552
# Hold id and Val: 1263, 1
# Class index: 1145, Frequency: 550
# Hold id and Val: 1359, 1
# Class index: 1695, Frequency: 549
# Hold id and Val: 1547, 3
# Class index: 39, Frequency: 548
# Hold id and Val: 1082, 3
# Class index: 380, Frequency: 544
# Hold id and Val: 1168, 0
# Class index: 1105, Frequency: 541
# Hold id and Val: 1349, 1
# Class index: 557, Frequency: 536
# Hold id and Val: 1212, 1
# Class index: 508, Frequency: 536
# Hold id and Val: 1200, 0
# Class index: 1427, Frequency: 534
# Hold id and Val: 1480, 3
# Class index: 525, Frequency: 533
# Hold id and Val: 1204, 1
# Class index: 1671, Frequency: 532
# Hold id and Val: 1541, 3
# Class index: 1201, Frequency: 531
# Hold id and Val: 1373, 1
# Class index: 1683, Frequency: 529
# Hold id and Val: 1544, 3
# Class index: 259, Frequency: 528
# Hold id and Val: 1137, 3
# Class index: 1439, Frequency: 520
# Hold id and Val: 1483, 3
# Class index: 493, Frequency: 520
# Hold id and Val: 1196, 1
# Class index: 449, Frequency: 510
# Hold id and Val: 1185, 1
# Class index: 729, Frequency: 506
# Hold id and Val: 1255, 1
# Class index: 1647, Frequency: 506
# Hold id and Val: 1535, 3
# Class index: 829, Frequency: 504
# Hold id and Val: 1280, 1
# Class index: 15, Frequency: 502
# Hold id and Val: 1076, 3
# Class index: 453, Frequency: 500
# Hold id and Val: 1186, 1
# Class index: 1639, Frequency: 499
# Hold id and Val: 1533, 3
# Class index: 1395, Frequency: 498
# Hold id and Val: 1472, 3
# Class index: 1627, Frequency: 496
# Hold id and Val: 1530, 3
# Class index: 327, Frequency: 492
# Hold id and Val: 1154, 3
# Class index: 236, Frequency: 490
# Hold id and Val: 1132, 0
# Class index: 1711, Frequency: 488
# Hold id and Val: 1551, 3
# Class index: 51, Frequency: 488
# Hold id and Val: 1085, 3
# Class index: 232, Frequency: 484
# Hold id and Val: 1131, 0
# Class index: 1185, Frequency: 483
# Hold id and Val: 1369, 1
# Class index: 292, Frequency: 483
# Hold id and Val: 1146, 0
# Class index: 1177, Frequency: 481
# Hold id and Val: 1367, 1
# Class index: 368, Frequency: 478
# Hold id and Val: 1165, 0
# Class index: 589, Frequency: 474
# Hold id and Val: 1220, 1
# Class index: 231, Frequency: 470
# Hold id and Val: 1130, 3
# Class index: 364, Frequency: 467
# Hold id and Val: 1164, 0
# Class index: 224, Frequency: 465
# Hold id and Val: 1129, 0
# Class index: 1579, Frequency: 465
# Hold id and Val: 1518, 3
# Class index: 1503, Frequency: 463
# Hold id and Val: 1499, 3
# Class index: 23, Frequency: 462
# Hold id and Val: 1078, 3
# Class index: 1611, Frequency: 461
# Hold id and Val: 1526, 3
# Class index: 448, Frequency: 460
# Hold id and Val: 1185, 0
# Class index: 661, Frequency: 459
# Hold id and Val: 1238, 1
# Class index: 673, Frequency: 458
# Hold id and Val: 1241, 1
# Class index: 1122, Frequency: 452
# Hold id and Val: 1353, 2
# Class index: 601, Frequency: 451
# Hold id and Val: 1223, 1
# Class index: 1483, Frequency: 448
# Hold id and Val: 1494, 3
# Class index: 1005, Frequency: 448
# Hold id and Val: 1324, 1
# Class index: 356, Frequency: 447
# Hold id and Val: 1162, 0
# Class index: 164, Frequency: 446
# Hold id and Val: 1114, 0
# Class index: 1575, Frequency: 446
# Hold id and Val: 1517, 3
# Class index: 1595, Frequency: 445
# Hold id and Val: 1522, 3
# Class index: 1009, Frequency: 443
# Hold id and Val: 1325, 1
# Class index: 208, Frequency: 439
# Hold id and Val: 1125, 0
# Class index: 272, Frequency: 439
# Hold id and Val: 1141, 0
# Class index: 897, Frequency: 432
# Hold id and Val: 1297, 1
# Class index: 577, Frequency: 430
# Hold id and Val: 1217, 1
# Class index: 352, Frequency: 428
# Hold id and Val: 1161, 0
# Class index: 311, Frequency: 427
# Hold id and Val: 1150, 3
# Class index: 324, Frequency: 427
# Hold id and Val: 1154, 0
# Class index: 428, Frequency: 426
# Hold id and Val: 1180, 0
# Class index: 1623, Frequency: 424
# Hold id and Val: 1529, 3
# Class index: 1511, Frequency: 423
# Hold id and Val: 1501, 3
# Class index: 1587, Frequency: 423
# Hold id and Val: 1520, 3
# Class index: 1141, Frequency: 422
# Hold id and Val: 1358, 1
# Class index: 1367, Frequency: 421
# Hold id and Val: 1465, 3
# Class index: 287, Frequency: 420
# Hold id and Val: 1144, 3
# Class index: 1567, Frequency: 419
# Hold id and Val: 1515, 3
# Class index: 375, Frequency: 417
# Hold id and Val: 1166, 3
# Class index: 295, Frequency: 417
# Hold id and Val: 1146, 3
# Class index: 67, Frequency: 416
# Hold id and Val: 1089, 3
# Class index: 489, Frequency: 415
# Hold id and Val: 1195, 1
# Class index: 1467, Frequency: 415
# Hold id and Val: 1490, 3
# Class index: 1751, Frequency: 414
# Hold id and Val: 1561, 3
# Class index: 424, Frequency: 413
# Hold id and Val: 1179, 0
# Class index: 1189, Frequency: 412
# Hold id and Val: 1370, 1
# Class index: 1699, Frequency: 412
# Hold id and Val: 1548, 3
# Class index: 308, Frequency: 411
# Hold id and Val: 1150, 0
# Class index: 83, Frequency: 408
# Hold id and Val: 1093, 3
# Class index: 240, Frequency: 407
# Hold id and Val: 1133, 0
# Class index: 1679, Frequency: 406
# Hold id and Val: 1543, 3
# Class index: 1583, Frequency: 405
# Hold id and Val: 1519, 3
# Class index: 1407, Frequency: 405
# Hold id and Val: 1475, 3
# Class index: 376, Frequency: 400
# Hold id and Val: 1167, 0
# Class index: 1209, Frequency: 397
# Hold id and Val: 1375, 1
# Class index: 889, Frequency: 396
# Hold id and Val: 1295, 1
# Class index: 1655, Frequency: 395
# Hold id and Val: 1537, 3
# Class index: 625, Frequency: 394
# Hold id and Val: 1229, 1
# Class index: 1719, Frequency: 394
# Hold id and Val: 1553, 3
# Class index: 937, Frequency: 393
# Hold id and Val: 1307, 1
# Class index: 363, Frequency: 392
# Hold id and Val: 1163, 3
# Class index: 412, Frequency: 389
# Hold id and Val: 1176, 0
# Class index: 3, Frequency: 388
# Hold id and Val: 1073, 3
# Class index: 319, Frequency: 387
# Hold id and Val: 1152, 3
# Class index: 1743, Frequency: 385
# Hold id and Val: 1559, 3
# Class index: 561, Frequency: 385
# Hold id and Val: 1213, 1
# Class index: 437, Frequency: 384
# Hold id and Val: 1182, 1
# Class index: 435, Frequency: 383
# Hold id and Val: 1181, 3
# Class index: 1735, Frequency: 383
# Hold id and Val: 1557, 3
# Class index: 19, Frequency: 381
# Hold id and Val: 1077, 3
# Class index: 151, Frequency: 381
# Hold id and Val: 1110, 3
# Class index: 111, Frequency: 378
# Hold id and Val: 1100, 3
# Class index: 212, Frequency: 377
# Hold id and Val: 1126, 0
# Class index: 511, Frequency: 372
# Hold id and Val: 1200, 3
# Class index: 361, Frequency: 369
# Hold id and Val: 1163, 1
# Class index: 445, Frequency: 369
# Hold id and Val: 1184, 1
# Class index: 388, Frequency: 368
# Hold id and Val: 1170, 0
# Class index: 1723, Frequency: 368
# Hold id and Val: 1554, 3
# Class index: 392, Frequency: 367
# Hold id and Val: 1171, 0
# Class index: 248, Frequency: 365
# Hold id and Val: 1135, 0
# Class index: 429, Frequency: 365
# Hold id and Val: 1180, 1
# Class index: 127, Frequency: 363
# Hold id and Val: 1104, 3
# Class index: 1205, Frequency: 361
# Hold id and Val: 1374, 1
# Class index: 1431, Frequency: 359
# Hold id and Val: 1481, 3
# Class index: 1443, Frequency: 357
# Hold id and Val: 1484, 3
# Class index: 476, Frequency: 356
# Hold id and Val: 1192, 0
# Class index: 1739, Frequency: 352
# Hold id and Val: 1558, 3
# Class index: 404, Frequency: 351
# Hold id and Val: 1174, 0
# Class index: 1371, Frequency: 350
# Hold id and Val: 1466, 3
# Class index: 436, Frequency: 349
# Hold id and Val: 1182, 0
# Class index: 529, Frequency: 347
# Hold id and Val: 1205, 1
# Class index: 1515, Frequency: 346
# Hold id and Val: 1502, 3
# Class index: 567, Frequency: 344
# Hold id and Val: 1214, 3
# Class index: 443, Frequency: 343
# Hold id and Val: 1183, 3
# Class index: 228, Frequency: 343
# Hold id and Val: 1130, 0
# Class index: 1547, Frequency: 340
# Hold id and Val: 1510, 3
# Class index: 135, Frequency: 340
# Hold id and Val: 1106, 3
# Class index: 420, Frequency: 339
# Hold id and Val: 1178, 0
# Class index: 1101, Frequency: 337
# Hold id and Val: 1348, 1
# Class index: 460, Frequency: 334
# Hold id and Val: 1188, 0
# Class index: 433, Frequency: 333
# Hold id and Val: 1181, 1
# Class index: 1555, Frequency: 333
# Hold id and Val: 1512, 3
# Class index: 893, Frequency: 333
# Hold id and Val: 1296, 1
# Class index: 885, Frequency: 332
# Hold id and Val: 1294, 1
# Class index: 79, Frequency: 331
# Hold id and Val: 1092, 3
# Class index: 139, Frequency: 327
# Hold id and Val: 1107, 3
# Class index: 457, Frequency: 324
# Hold id and Val: 1187, 1
# Class index: 456, Frequency: 324
# Hold id and Val: 1187, 0
# Class index: 520, Frequency: 323
# Hold id and Val: 1203, 0
# Class index: 416, Frequency: 321
# Hold id and Val: 1177, 0
# Class index: 123, Frequency: 321
# Hold id and Val: 1103, 3
# Class index: 396, Frequency: 320
# Hold id and Val: 1172, 0
# Class index: 332, Frequency: 320
# Hold id and Val: 1156, 0
# Class index: 516, Frequency: 316
# Hold id and Val: 1202, 0
# Class index: 669, Frequency: 316
# Hold id and Val: 1240, 1
# Class index: 1663, Frequency: 314
# Hold id and Val: 1539, 3
# Class index: 825, Frequency: 314
# Hold id and Val: 1279, 1
# Class index: 1173, Frequency: 313
# Hold id and Val: 1366, 1
# Class index: 689, Frequency: 311
# Hold id and Val: 1245, 1
# Class index: 1747, Frequency: 310
# Hold id and Val: 1560, 3
# Class index: 441, Frequency: 310
# Hold id and Val: 1183, 1
# Class index: 805, Frequency: 304
# Hold id and Val: 1274, 1
# Class index: 1198, Frequency: 303
# Hold id and Val: 1372, 2
# Class index: 425, Frequency: 301
# Hold id and Val: 1179, 1
# Class index: 291, Frequency: 300
# Hold id and Val: 1145, 3
# Class index: 432, Frequency: 296
# Hold id and Val: 1181, 0
# Class index: 391, Frequency: 296
# Hold id and Val: 1170, 3
# Class index: 387, Frequency: 295
# Hold id and Val: 1169, 3
# Class index: 527, Frequency: 292
# Hold id and Val: 1204, 3
# Class index: 59, Frequency: 291
# Hold id and Val: 1087, 3
# Class index: 1615, Frequency: 287
# Hold id and Val: 1527, 3
# Class index: 1359, Frequency: 286
# Hold id and Val: 1463, 3
# Class index: 444, Frequency: 285
# Hold id and Val: 1184, 0
# Class index: 1299, Frequency: 285
# Hold id and Val: 1448, 3
# Class index: 549, Frequency: 284
# Hold id and Val: 1210, 1
# Class index: 348, Frequency: 284
# Hold id and Val: 1160, 0
# Class index: 1013, Frequency: 283
# Hold id and Val: 1326, 1
# Class index: 1715, Frequency: 282
# Hold id and Val: 1552, 3
# Class index: 371, Frequency: 281
# Hold id and Val: 1165, 3
# Class index: 260, Frequency: 279
# Hold id and Val: 1138, 0
# Class index: 464, Frequency: 277
# Hold id and Val: 1189, 0
# Class index: 256, Frequency: 277
# Hold id and Val: 1137, 0
# Class index: 523, Frequency: 277
# Hold id and Val: 1203, 3
# Class index: 644, Frequency: 277
# Hold id and Val: 1234, 0
# Class index: 1707, Frequency: 276
# Hold id and Val: 1550, 3
# Class index: 179, Frequency: 276
# Hold id and Val: 1117, 3
# Class index: 204, Frequency: 273
# Hold id and Val: 1124, 0
# Class index: 279, Frequency: 272
# Hold id and Val: 1142, 3
# Class index: 383, Frequency: 271
# Hold id and Val: 1168, 3
# Class index: 339, Frequency: 268
# Hold id and Val: 1157, 3
# Class index: 1077, Frequency: 268
# Hold id and Val: 1342, 1
# Class index: 1703, Frequency: 267
# Hold id and Val: 1549, 3
# Class index: 617, Frequency: 263
# Hold id and Val: 1227, 1
# Class index: 1619, Frequency: 263
# Hold id and Val: 1528, 3
# Class index: 496, Frequency: 263
# Hold id and Val: 1197, 0
# Class index: 440, Frequency: 262
# Hold id and Val: 1183, 0
# Class index: 385, Frequency: 262
# Hold id and Val: 1169, 1
# Class index: 757, Frequency: 261
# Hold id and Val: 1262, 1
# Class index: 524, Frequency: 261
# Hold id and Val: 1204, 0
# Class index: 183, Frequency: 261
# Hold id and Val: 1118, 3
# Class index: 312, Frequency: 260
# Hold id and Val: 1151, 0
# Class index: 753, Frequency: 260
# Hold id and Val: 1261, 1
# Class index: 1169, Frequency: 260
# Hold id and Val: 1365, 1
# Class index: 315, Frequency: 259
# Hold id and Val: 1151, 3
# Class index: 408, Frequency: 257
# Hold id and Val: 1175, 0
# Class index: 1727, Frequency: 256
# Hold id and Val: 1555, 3
# Class index: 1089, Frequency: 254
# Hold id and Val: 1345, 1
# Class index: 1085, Frequency: 253
# Hold id and Val: 1344, 1
# Class index: 395, Frequency: 253
# Hold id and Val: 1171, 3
# Class index: 1543, Frequency: 252
# Hold id and Val: 1509, 3
# Class index: 71, Frequency: 251
# Hold id and Val: 1090, 3
# Class index: 1755, Frequency: 250
# Hold id and Val: 1562, 3
# Class index: 1029, Frequency: 250
# Hold id and Val: 1330, 1
# Class index: 504, Frequency: 249
# Hold id and Val: 1199, 0
# Class index: 741, Frequency: 248
# Hold id and Val: 1258, 1
# Class index: 1475, Frequency: 248
# Hold id and Val: 1492, 3
# Class index: 421, Frequency: 248
# Hold id and Val: 1178, 1
# Class index: 559, Frequency: 248
# Hold id and Val: 1212, 3
# Class index: 667, Frequency: 247
# Hold id and Val: 1239, 3
# Class index: 264, Frequency: 246
# Hold id and Val: 1139, 0
# Class index: 355, Frequency: 246
# Hold id and Val: 1161, 3
# Class index: 468, Frequency: 246
# Hold id and Val: 1190, 0
# Class index: 107, Frequency: 246
# Hold id and Val: 1099, 3
# Class index: 191, Frequency: 244
# Hold id and Val: 1120, 3
# Class index: 1795, Frequency: 244
# Hold id and Val: 1572, 3
# Class index: 63, Frequency: 243
# Hold id and Val: 1088, 3
# Class index: 477, Frequency: 243
# Hold id and Val: 1192, 1
# Class index: 1691, Frequency: 241
# Hold id and Val: 1546, 3
# Class index: 1399, Frequency: 240
# Hold id and Val: 1473, 3
# Class index: 485, Frequency: 239
# Hold id and Val: 1194, 1
# Class index: 512, Frequency: 238
# Hold id and Val: 1201, 0
# Class index: 591, Frequency: 238
# Hold id and Val: 1220, 3
# Class index: 472, Frequency: 236
# Hold id and Val: 1191, 0
# Class index: 681, Frequency: 235
# Hold id and Val: 1243, 1
# Class index: 1025, Frequency: 235
# Hold id and Val: 1329, 1
# Class index: 275, Frequency: 233
# Hold id and Val: 1141, 3
# Class index: 492, Frequency: 233
# Hold id and Val: 1196, 0
# Class index: 75, Frequency: 231
# Hold id and Val: 1091, 3
# Class index: 1779, Frequency: 231
# Hold id and Val: 1568, 3
# Class index: 1771, Frequency: 229
# Hold id and Val: 1566, 3
# Class index: 1403, Frequency: 229
# Hold id and Val: 1474, 3
# Class index: 531, Frequency: 228
# Hold id and Val: 1205, 3
# Class index: 961, Frequency: 223
# Hold id and Val: 1313, 1
# Class index: 1787, Frequency: 222
# Hold id and Val: 1570, 3
# Class index: 335, Frequency: 222
# Hold id and Val: 1156, 3
# Class index: 1687, Frequency: 219
# Hold id and Val: 1545, 3
# Class index: 945, Frequency: 217
# Hold id and Val: 1309, 1
# Class index: 271, Frequency: 216
# Hold id and Val: 1140, 3
# Class index: 1659, Frequency: 216
# Hold id and Val: 1538, 3
# Class index: 219, Frequency: 215
# Hold id and Val: 1127, 3
# Class index: 373, Frequency: 214
# Hold id and Val: 1166, 1
# Class index: 381, Frequency: 213
# Hold id and Val: 1168, 1
# Class index: 587, Frequency: 212
# Hold id and Val: 1219, 3
# Class index: 400, Frequency: 211
# Hold id and Val: 1173, 0
# Class index: 475, Frequency: 209
# Hold id and Val: 1191, 3
# Class index: 7, Frequency: 209
# Hold id and Val: 1074, 3
# Class index: 461, Frequency: 209
# Hold id and Val: 1188, 1
# Class index: 11, Frequency: 208
# Hold id and Val: 1075, 3
# Class index: 813, Frequency: 207
# Hold id and Val: 1276, 1
# Class index: 1471, Frequency: 207
# Hold id and Val: 1491, 3
# Class index: 592, Frequency: 206
# Hold id and Val: 1221, 0
# Class index: 736, Frequency: 204
# Hold id and Val: 1257, 0
# Class index: 176, Frequency: 203
# Hold id and Val: 1117, 0
# Class index: 635, Frequency: 202
# Hold id and Val: 1231, 3
# Class index: 463, Frequency: 201
# Hold id and Val: 1188, 3
# Class index: 1673, Frequency: 199
# Hold id and Val: 1542, 1
# Class index: 499, Frequency: 198
# Hold id and Val: 1197, 3
# Class index: 821, Frequency: 198
# Hold id and Val: 1278, 1
# Class index: 957, Frequency: 198
# Hold id and Val: 1312, 1
# Class index: 533, Frequency: 196
# Hold id and Val: 1206, 1
# Class index: 749, Frequency: 195
# Hold id and Val: 1260, 1
# Class index: 695, Frequency: 194
# Hold id and Val: 1246, 3
# Class index: 1817, Frequency: 193
# Hold id and Val: 1578, 1
# Class index: 731, Frequency: 192
# Hold id and Val: 1255, 3
# Class index: 528, Frequency: 192
# Hold id and Val: 1205, 0
# Class index: 1249, Frequency: 191
# Hold id and Val: 1385, 1
# Class index: 679, Frequency: 190
# Hold id and Val: 1242, 3
# Class index: 535, Frequency: 189
# Hold id and Val: 1206, 3
# Class index: 144, Frequency: 189
# Hold id and Val: 1109, 0
# Class index: 1081, Frequency: 187
# Hold id and Val: 1343, 1
# Class index: 564, Frequency: 187
# Hold id and Val: 1214, 0
# Class index: 1178, Frequency: 186
# Hold id and Val: 1367, 2
# Class index: 1257, Frequency: 184
# Hold id and Val: 1387, 1
# Class index: 600, Frequency: 183
# Hold id and Val: 1223, 0
# Class index: 551, Frequency: 180
# Hold id and Val: 1210, 3
# Class index: 359, Frequency: 179
# Hold id and Val: 1162, 3
# Class index: 1677, Frequency: 178
# Hold id and Val: 1543, 1
# Class index: 413, Frequency: 177
# Hold id and Val: 1176, 1
# Class index: 795, Frequency: 175
# Hold id and Val: 1271, 3
# Class index: 877, Frequency: 175
# Hold id and Val: 1292, 1
# Class index: 305, Frequency: 172
# Hold id and Val: 1149, 1
# Class index: 595, Frequency: 172
# Hold id and Val: 1221, 3
# Class index: 543, Frequency: 171
# Hold id and Val: 1208, 3
# Class index: 515, Frequency: 170
# Hold id and Val: 1201, 3
# Class index: 652, Frequency: 170
# Hold id and Val: 1236, 0
# Class index: 488, Frequency: 169
# Hold id and Val: 1195, 0
# Class index: 572, Frequency: 168
# Hold id and Val: 1216, 0
# Class index: 745, Frequency: 168
# Hold id and Val: 1259, 1
# Class index: 1265, Frequency: 167
# Hold id and Val: 1389, 1
# Class index: 344, Frequency: 166
# Hold id and Val: 1159, 0
# Class index: 377, Frequency: 165
# Hold id and Val: 1167, 1
# Class index: 369, Frequency: 164
# Hold id and Val: 1165, 1
# Class index: 739, Frequency: 164
# Hold id and Val: 1257, 3
# Class index: 1273, Frequency: 162
# Hold id and Val: 1391, 1
# Class index: 417, Frequency: 161
# Hold id and Val: 1177, 1
# Class index: 659, Frequency: 157
# Hold id and Val: 1237, 3
# Class index: 685, Frequency: 157
# Hold id and Val: 1244, 1
# Class index: 568, Frequency: 157
# Hold id and Val: 1215, 0
# Class index: 583, Frequency: 156
# Hold id and Val: 1218, 3
# Class index: 365, Frequency: 155
# Hold id and Val: 1164, 1
# Class index: 1731, Frequency: 154
# Hold id and Val: 1556, 3
# Class index: 953, Frequency: 154
# Hold id and Val: 1311, 1
# Class index: 156, Frequency: 154
# Hold id and Val: 1112, 0
# Class index: 545, Frequency: 154
# Hold id and Val: 1209, 1
# Class index: 351, Frequency: 151
# Hold id and Val: 1160, 3
# Class index: 1153, Frequency: 151
# Hold id and Val: 1361, 1
# Class index: 1705, Frequency: 151
# Hold id and Val: 1550, 1
# Class index: 155, Frequency: 151
# Hold id and Val: 1111, 3
# Class index: 1213, Frequency: 150
# Hold id and Val: 1376, 1
# Class index: 647, Frequency: 150
# Hold id and Val: 1234, 3
# Class index: 403, Frequency: 149
# Hold id and Val: 1173, 3
# Class index: 268, Frequency: 149
# Hold id and Val: 1140, 0
# Class index: 648, Frequency: 149
# Hold id and Val: 1235, 0
# Class index: 1775, Frequency: 147
# Hold id and Val: 1567, 3
# Class index: 1783, Frequency: 147
# Hold id and Val: 1569, 3
# Class index: 184, Frequency: 146
# Hold id and Val: 1119, 0
# Class index: 481, Frequency: 145
# Hold id and Val: 1193, 1
# Class index: 563, Frequency: 143
# Hold id and Val: 1213, 3
# Class index: 1791, Frequency: 143
# Hold id and Val: 1571, 3
# Class index: 103, Frequency: 142
# Hold id and Val: 1098, 3
# Class index: 537, Frequency: 140
# Hold id and Val: 1207, 1
# Class index: 1098, Frequency: 140
# Hold id and Val: 1347, 2
# Class index: 1759, Frequency: 139
# Hold id and Val: 1563, 3
# Class index: 1767, Frequency: 139
# Hold id and Val: 1565, 3
# Class index: 465, Frequency: 138
# Hold id and Val: 1189, 1
# Class index: 340, Frequency: 137
# Hold id and Val: 1158, 0
# Class index: 1741, Frequency: 137
# Hold id and Val: 1559, 1
# Class index: 1194, Frequency: 136
# Hold id and Val: 1371, 2
# Class index: 172, Frequency: 136
# Hold id and Val: 1116, 0
# Class index: 484, Frequency: 135
# Hold id and Val: 1194, 0
# Class index: 487, Frequency: 134
# Hold id and Val: 1194, 3
# Class index: 1241, Frequency: 133
# Hold id and Val: 1383, 1
# Class index: 297, Frequency: 133
# Hold id and Val: 1147, 1
# Class index: 1669, Frequency: 132
# Hold id and Val: 1541, 1
# Class index: 1149, Frequency: 131
# Hold id and Val: 1360, 1
# Class index: 168, Frequency: 131
# Hold id and Val: 1115, 0
# Class index: 1597, Frequency: 130
# Hold id and Val: 1523, 1
# Class index: 640, Frequency: 130
# Hold id and Val: 1233, 0
# Class index: 423, Frequency: 129
# Hold id and Val: 1178, 3
# Class index: 200, Frequency: 127
# Hold id and Val: 1123, 0
# Class index: 1781, Frequency: 127
# Hold id and Val: 1569, 1
# Class index: 188, Frequency: 125
# Hold id and Val: 1120, 0
# Class index: 620, Frequency: 125
# Hold id and Val: 1228, 0
# Class index: 301, Frequency: 124
# Hold id and Val: 1148, 1
# Class index: 1146, Frequency: 124
# Hold id and Val: 1359, 2
# Class index: 651, Frequency: 124
# Hold id and Val: 1235, 3
# Class index: 664, Frequency: 124
# Hold id and Val: 1239, 0
# Class index: 548, Frequency: 123
# Hold id and Val: 1210, 0
# Class index: 180, Frequency: 122
# Hold id and Val: 1118, 0
# Class index: 532, Frequency: 122
# Hold id and Val: 1206, 0
# Class index: 192, Frequency: 122
# Hold id and Val: 1121, 0
# Class index: 1017, Frequency: 120
# Hold id and Val: 1327, 1
# Class index: 1093, Frequency: 120
# Hold id and Val: 1346, 1
# Class index: 628, Frequency: 120
# Hold id and Val: 1230, 0
# Class index: 643, Frequency: 118
# Hold id and Val: 1233, 3
# Class index: 143, Frequency: 118
# Hold id and Val: 1108, 3
# Class index: 881, Frequency: 118
# Hold id and Val: 1293, 1
# Class index: 719, Frequency: 118
# Hold id and Val: 1252, 3
# Class index: 809, Frequency: 117
# Hold id and Val: 1275, 1
# Class index: 867, Frequency: 116
# Hold id and Val: 1289, 3
# Class index: 609, Frequency: 116
# Hold id and Val: 1225, 1
# Class index: 389, Frequency: 116
# Hold id and Val: 1170, 1
# Class index: 556, Frequency: 115
# Hold id and Val: 1212, 0
# Class index: 357, Frequency: 115
# Hold id and Val: 1162, 1
# Class index: 1827, Frequency: 114
# Hold id and Val: 1580, 3
# Class index: 479, Frequency: 114
# Hold id and Val: 1192, 3
# Class index: 744, Frequency: 114
# Hold id and Val: 1259, 0
# Class index: 584, Frequency: 113
# Hold id and Val: 1219, 0
# Class index: 1819, Frequency: 113
# Hold id and Val: 1578, 3
# Class index: 1269, Frequency: 112
# Hold id and Val: 1390, 1
# Class index: 1210, Frequency: 112
# Hold id and Val: 1375, 2
# Class index: 711, Frequency: 108
# Hold id and Val: 1250, 3
# Class index: 480, Frequency: 108
# Hold id and Val: 1193, 0
# Class index: 303, Frequency: 107
# Hold id and Val: 1148, 3
# Class index: 469, Frequency: 107
# Hold id and Val: 1190, 1
# Class index: 536, Frequency: 106
# Hold id and Val: 1207, 0
# Class index: 1807, Frequency: 105
# Hold id and Val: 1575, 3
# Class index: 763, Frequency: 105
# Hold id and Val: 1263, 3
# Class index: 1701, Frequency: 105
# Hold id and Val: 1549, 1
# Class index: 613, Frequency: 104
# Hold id and Val: 1226, 1
# Class index: 1158, Frequency: 104
# Hold id and Val: 1362, 2
# Class index: 1823, Frequency: 104
# Hold id and Val: 1579, 3
# Class index: 596, Frequency: 102
# Hold id and Val: 1222, 0
# Class index: 1245, Frequency: 101
# Hold id and Val: 1384, 1
# Class index: 807, Frequency: 100
# Hold id and Val: 1274, 3
# Class index: 817, Frequency: 100
# Hold id and Val: 1277, 1
# Class index: 747, Frequency: 99
# Hold id and Val: 1259, 3
# Class index: 411, Frequency: 98
# Hold id and Val: 1175, 3
# Class index: 707, Frequency: 98
# Hold id and Val: 1249, 3
# Class index: 803, Frequency: 98
# Hold id and Val: 1273, 3
# Class index: 615, Frequency: 97
# Hold id and Val: 1226, 3
# Class index: 544, Frequency: 97
# Hold id and Val: 1209, 0
# Class index: 1813, Frequency: 96
# Hold id and Val: 1577, 1
# Class index: 1809, Frequency: 95
# Hold id and Val: 1576, 1
# Class index: 87, Frequency: 94
# Hold id and Val: 1094, 3
# Class index: 632, Frequency: 93
# Hold id and Val: 1231, 0
# Class index: 455, Frequency: 93
# Hold id and Val: 1186, 3
# Class index: 942, Frequency: 92
# Hold id and Val: 1308, 2
# Class index: 503, Frequency: 92
# Hold id and Val: 1198, 3
# Class index: 1190, Frequency: 92
# Hold id and Val: 1370, 2
# Class index: 1881, Frequency: 91
# Hold id and Val: 1594, 1
# Class index: 949, Frequency: 91
# Hold id and Val: 1310, 1
# Class index: 495, Frequency: 91
# Hold id and Val: 1196, 3
# Class index: 986, Frequency: 91
# Hold id and Val: 1319, 2
# Class index: 353, Frequency: 91
# Hold id and Val: 1161, 1
# Class index: 1253, Frequency: 90
# Hold id and Val: 1386, 1
# Class index: 104, Frequency: 90
# Hold id and Val: 1099, 0
# Class index: 683, Frequency: 89
# Hold id and Val: 1243, 3
# Class index: 580, Frequency: 89
# Hold id and Val: 1218, 0
# Class index: 171, Frequency: 89
# Hold id and Val: 1115, 3
# Class index: 1893, Frequency: 89
# Hold id and Val: 1597, 1
# Class index: 576, Frequency: 88
# Hold id and Val: 1217, 0
# Class index: 1021, Frequency: 88
# Hold id and Val: 1328, 1
# Class index: 715, Frequency: 88
# Hold id and Val: 1251, 3
# Class index: 1665, Frequency: 88
# Hold id and Val: 1540, 1
# Class index: 540, Frequency: 87
# Hold id and Val: 1208, 0
# Class index: 439, Frequency: 87
# Hold id and Val: 1182, 3
# Class index: 571, Frequency: 87
# Hold id and Val: 1215, 3
# Class index: 471, Frequency: 87
# Hold id and Val: 1190, 3
# Class index: 779, Frequency: 86
# Hold id and Val: 1267, 3
# Class index: 656, Frequency: 86
# Hold id and Val: 1237, 0
# Class index: 687, Frequency: 86
# Hold id and Val: 1244, 3
# Class index: 553, Frequency: 85
# Hold id and Val: 1211, 1
# Class index: 918, Frequency: 85
# Hold id and Val: 1302, 2
# Class index: 115, Frequency: 84
# Hold id and Val: 1101, 3
# Class index: 835, Frequency: 84
# Hold id and Val: 1281, 3
# Class index: 787, Frequency: 84
# Hold id and Val: 1269, 3
# Class index: 491, Frequency: 84
# Hold id and Val: 1195, 3
# Class index: 196, Frequency: 83
# Hold id and Val: 1122, 0
# Class index: 1556, Frequency: 83
# Hold id and Val: 1513, 0
# Class index: 343, Frequency: 83
# Hold id and Val: 1158, 3
# Class index: 393, Frequency: 82
# Hold id and Val: 1171, 1
# Class index: 148, Frequency: 81
# Hold id and Val: 1110, 0
# Class index: 152, Frequency: 81
# Hold id and Val: 1111, 0
# Class index: 91, Frequency: 81
# Hold id and Val: 1095, 3
# Class index: 1261, Frequency: 81
# Hold id and Val: 1388, 1
# Class index: 677, Frequency: 80
# Hold id and Val: 1242, 1
# Class index: 1561, Frequency: 80
# Hold id and Val: 1514, 1
# Class index: 1182, Frequency: 80
# Hold id and Val: 1368, 2
# Class index: 321, Frequency: 80
# Hold id and Val: 1153, 1
# Class index: 1090, Frequency: 79
# Hold id and Val: 1345, 2
# Class index: 1552, Frequency: 79
# Hold id and Val: 1512, 0
# Class index: 605, Frequency: 78
# Hold id and Val: 1224, 1
# Class index: 771, Frequency: 78
# Hold id and Val: 1265, 3
# Class index: 447, Frequency: 77
# Hold id and Val: 1184, 3
# Class index: 1763, Frequency: 77
# Hold id and Val: 1564, 3
# Class index: 1162, Frequency: 77
# Hold id and Val: 1363, 2
# Class index: 723, Frequency: 77
# Hold id and Val: 1253, 3
# Class index: 140, Frequency: 76
# Hold id and Val: 1108, 0
# Class index: 1074, Frequency: 76
# Hold id and Val: 1341, 2
# Class index: 136, Frequency: 76
# Hold id and Val: 1107, 0
# Class index: 92, Frequency: 76
# Hold id and Val: 1096, 0
# Class index: 1831, Frequency: 75
# Hold id and Val: 1581, 3
# Class index: 672, Frequency: 75
# Hold id and Val: 1241, 0
# Class index: 1174, Frequency: 75
# Hold id and Val: 1366, 2
# Class index: 409, Frequency: 74
# Hold id and Val: 1175, 1
# Class index: 1557, Frequency: 74
# Hold id and Val: 1513, 1
# Class index: 575, Frequency: 74
# Hold id and Val: 1216, 3
# Class index: 1815, Frequency: 73
# Hold id and Val: 1577, 3
# Class index: 507, Frequency: 73
# Hold id and Val: 1199, 3
# Class index: 1560, Frequency: 73
# Hold id and Val: 1514, 0
# Class index: 519, Frequency: 73
# Hold id and Val: 1202, 3
# Class index: 1803, Frequency: 73
# Hold id and Val: 1574, 3
# Class index: 1564, Frequency: 73
# Hold id and Val: 1515, 0
# Class index: 167, Frequency: 73
# Hold id and Val: 1114, 3
# Class index: 655, Frequency: 72
# Hold id and Val: 1236, 3
# Class index: 541, Frequency: 72
# Hold id and Val: 1208, 1
# Class index: 131, Frequency: 72
# Hold id and Val: 1105, 3
# Class index: 1165, Frequency: 72
# Hold id and Val: 1364, 1
# Class index: 119, Frequency: 72
# Hold id and Val: 1102, 3
# Class index: 1605, Frequency: 71
# Hold id and Val: 1525, 1
# Class index: 791, Frequency: 71
# Hold id and Val: 1270, 3
# Class index: 160, Frequency: 70
# Hold id and Val: 1113, 0
# Class index: 579, Frequency: 69
# Hold id and Val: 1217, 3
# Class index: 1237, Frequency: 69
# Hold id and Val: 1382, 1
# Class index: 1516, Frequency: 69
# Hold id and Val: 1503, 0
# Class index: 199, Frequency: 69
# Hold id and Val: 1122, 3
# Class index: 1170, Frequency: 68
# Hold id and Val: 1365, 2
# Class index: 1749, Frequency: 68
# Hold id and Val: 1561, 1
# Class index: 696, Frequency: 68
# Hold id and Val: 1247, 0
# Class index: 1773, Frequency: 67
# Hold id and Val: 1567, 1
# Class index: 708, Frequency: 67
# Hold id and Val: 1250, 0
# Class index: 934, Frequency: 67
# Hold id and Val: 1306, 2
# Class index: 1568, Frequency: 66
# Hold id and Val: 1516, 0
# Class index: 823, Frequency: 66
# Hold id and Val: 1278, 3
# Class index: 588, Frequency: 65
# Hold id and Val: 1220, 0
# Class index: 1553, Frequency: 65
# Hold id and Val: 1512, 1
# Class index: 560, Frequency: 64
# Hold id and Val: 1213, 0
# Class index: 1811, Frequency: 64
# Hold id and Val: 1576, 3
# Class index: 1217, Frequency: 64
# Hold id and Val: 1377, 1
# Class index: 1565, Frequency: 64
# Hold id and Val: 1515, 1
# Class index: 608, Frequency: 63
# Hold id and Val: 1225, 0
# Class index: 307, Frequency: 63
# Hold id and Val: 1149, 3
# Class index: 1166, Frequency: 62
# Hold id and Val: 1364, 2
# Class index: 1488, Frequency: 62
# Hold id and Val: 1496, 0
# Class index: 639, Frequency: 61
# Hold id and Val: 1232, 3
# Class index: 1839, Frequency: 61
# Hold id and Val: 1583, 3
# Class index: 1867, Frequency: 61
# Hold id and Val: 1590, 3
# Class index: 636, Frequency: 60
# Hold id and Val: 1232, 0
# Class index: 317, Frequency: 60
# Hold id and Val: 1152, 1
# Class index: 1222, Frequency: 60
# Hold id and Val: 1378, 2
# Class index: 703, Frequency: 60
# Hold id and Val: 1248, 3
# Class index: 1709, Frequency: 60
# Hold id and Val: 1551, 1
# Class index: 660, Frequency: 59
# Hold id and Val: 1238, 0
# Class index: 1130, Frequency: 59
# Hold id and Val: 1355, 2
# Class index: 116, Frequency: 59
# Hold id and Val: 1102, 0
# Class index: 255, Frequency: 59
# Hold id and Val: 1136, 3
# Class index: 473, Frequency: 59
# Hold id and Val: 1191, 1
# Class index: 1034, Frequency: 58
# Hold id and Val: 1331, 2
# Class index: 604, Frequency: 58
# Hold id and Val: 1224, 0
# Class index: 1859, Frequency: 58
# Hold id and Val: 1588, 3
# Class index: 1733, Frequency: 58
# Hold id and Val: 1557, 1
# Class index: 886, Frequency: 58
# Hold id and Val: 1294, 2
# Class index: 1206, Frequency: 57
# Hold id and Val: 1374, 2
# Class index: 96, Frequency: 57
# Hold id and Val: 1097, 0
# Class index: 811, Frequency: 56
# Hold id and Val: 1275, 3
# Class index: 1799, Frequency: 56
# Hold id and Val: 1573, 3
# Class index: 347, Frequency: 56
# Hold id and Val: 1159, 3
# Class index: 309, Frequency: 56
# Hold id and Val: 1150, 1
# Class index: 251, Frequency: 55
# Hold id and Val: 1135, 3
# Class index: 1186, Frequency: 55
# Hold id and Val: 1369, 2
# Class index: 1214, Frequency: 55
# Hold id and Val: 1376, 2
# Class index: 1681, Frequency: 55
# Hold id and Val: 1544, 1
# Class index: 1851, Frequency: 55
# Hold id and Val: 1586, 3
# Class index: 699, Frequency: 54
# Hold id and Val: 1247, 3
# Class index: 616, Frequency: 54
# Hold id and Val: 1227, 0
# Class index: 88, Frequency: 54
# Hold id and Val: 1095, 0
# Class index: 899, Frequency: 54
# Hold id and Val: 1297, 3
# Class index: 1889, Frequency: 54
# Hold id and Val: 1596, 1
# Class index: 1637, Frequency: 54
# Hold id and Val: 1533, 1
# Class index: 1625, Frequency: 54
# Hold id and Val: 1530, 1
# Class index: 1277, Frequency: 53
# Hold id and Val: 1392, 1
# Class index: 1661, Frequency: 53
# Hold id and Val: 1539, 1
# Class index: 293, Frequency: 53
# Hold id and Val: 1146, 1
# Class index: 692, Frequency: 52
# Hold id and Val: 1246, 0
# Class index: 1492, Frequency: 52
# Hold id and Val: 1497, 0
# Class index: 855, Frequency: 52
# Hold id and Val: 1286, 3
# Class index: 349, Frequency: 52
# Hold id and Val: 1160, 1
# Class index: 935, Frequency: 52
# Hold id and Val: 1306, 3
# Class index: 397, Frequency: 52
# Hold id and Val: 1172, 1
# Class index: 1532, Frequency: 51
# Hold id and Val: 1507, 0
# Class index: 910, Frequency: 51
# Hold id and Val: 1300, 2
# Class index: 1853, Frequency: 51
# Hold id and Val: 1587, 1
# Class index: 1589, Frequency: 51
# Hold id and Val: 1521, 1
# Class index: 1825, Frequency: 51
# Hold id and Val: 1580, 1
# Class index: 1161, Frequency: 51
# Hold id and Val: 1363, 1
# Class index: 759, Frequency: 50
# Hold id and Val: 1262, 3
# Class index: 1697, Frequency: 50
# Hold id and Val: 1548, 1
# Class index: 1633, Frequency: 50
# Hold id and Val: 1532, 1
# Class index: 724, Frequency: 50
# Hold id and Val: 1254, 0
# Class index: 1218, Frequency: 50
# Hold id and Val: 1377, 2
# Class index: 1154, Frequency: 49
# Hold id and Val: 1361, 2
# Class index: 1202, Frequency: 49
# Hold id and Val: 1373, 2
# Class index: 727, Frequency: 49
# Hold id and Val: 1254, 3
# Class index: 839, Frequency: 48
# Hold id and Val: 1282, 3
# Class index: 1134, Frequency: 48
# Hold id and Val: 1356, 2
# Class index: 175, Frequency: 48
# Hold id and Val: 1116, 3
# Class index: 668, Frequency: 48
# Hold id and Val: 1240, 0
# Class index: 1444, Frequency: 47
# Hold id and Val: 1485, 0
# Class index: 203, Frequency: 47
# Hold id and Val: 1123, 3
# Class index: 227, Frequency: 47
# Hold id and Val: 1129, 3
# Class index: 325, Frequency: 47
# Hold id and Val: 1154, 1
# Class index: 159, Frequency: 47
# Hold id and Val: 1112, 3
# Class index: 1855, Frequency: 47
# Hold id and Val: 1587, 3
# Class index: 451, Frequency: 46
# Hold id and Val: 1185, 3
# Class index: 399, Frequency: 46
# Hold id and Val: 1172, 3
# Class index: 671, Frequency: 45
# Hold id and Val: 1240, 3
# Class index: 80, Frequency: 45
# Hold id and Val: 1093, 0
# Class index: 1629, Frequency: 45
# Hold id and Val: 1531, 1
# Class index: 1221, Frequency: 45
# Hold id and Val: 1378, 1
# Class index: 1512, Frequency: 44
# Hold id and Val: 1502, 0
# Class index: 859, Frequency: 44
# Hold id and Val: 1287, 3
# Class index: 1885, Frequency: 44
# Hold id and Val: 1595, 1
# Class index: 1863, Frequency: 44
# Hold id and Val: 1589, 3
# Class index: 299, Frequency: 43
# Hold id and Val: 1147, 3
# Class index: 289, Frequency: 43
# Hold id and Val: 1145, 1
# Class index: 1070, Frequency: 43
# Hold id and Val: 1340, 2
# Class index: 603, Frequency: 43
# Hold id and Val: 1223, 3
# Class index: 1520, Frequency: 43
# Hold id and Val: 1504, 0
# Class index: 688, Frequency: 43
# Hold id and Val: 1245, 0
# Class index: 427, Frequency: 43
# Hold id and Val: 1179, 3
# Class index: 792, Frequency: 43
# Hold id and Val: 1271, 0
# Class index: 233, Frequency: 42
# Hold id and Val: 1131, 1
# Class index: 1118, Frequency: 42
# Hold id and Val: 1352, 2
# Class index: 313, Frequency: 42
# Hold id and Val: 1151, 1
# Class index: 1849, Frequency: 42
# Hold id and Val: 1586, 1
# Class index: 1745, Frequency: 42
# Hold id and Val: 1560, 1
# Class index: 680, Frequency: 42
# Hold id and Val: 1243, 0
# Class index: 1452, Frequency: 41
# Hold id and Val: 1487, 0
# Class index: 738, Frequency: 41
# Hold id and Val: 1257, 2
# Class index: 120, Frequency: 41
# Hold id and Val: 1103, 0
# Class index: 285, Frequency: 41
# Hold id and Val: 1144, 1
# Class index: 1777, Frequency: 41
# Hold id and Val: 1568, 1
# Class index: 863, Frequency: 41
# Hold id and Val: 1288, 3
# Class index: 847, Frequency: 41
# Hold id and Val: 1284, 3
# Class index: 1596, Frequency: 41
# Hold id and Val: 1523, 0
# Class index: 700, Frequency: 41
# Hold id and Val: 1248, 0
# Class index: 245, Frequency: 40
# Hold id and Val: 1134, 1
# Class index: 1138, Frequency: 40
# Hold id and Val: 1357, 2
# Class index: 108, Frequency: 40
# Hold id and Val: 1100, 0
# Class index: 239, Frequency: 40
# Hold id and Val: 1132, 3
# Class index: 1569, Frequency: 40
# Hold id and Val: 1516, 1
# Class index: 931, Frequency: 40
# Hold id and Val: 1305, 3
# Class index: 1042, Frequency: 39
# Hold id and Val: 1333, 2
# Class index: 732, Frequency: 39
# Hold id and Val: 1256, 0
# Class index: 919, Frequency: 39
# Hold id and Val: 1302, 3
# Class index: 1843, Frequency: 39
# Hold id and Val: 1584, 3
# Class index: 1877, Frequency: 39
# Hold id and Val: 1593, 1
# Class index: 939, Frequency: 39
# Hold id and Val: 1307, 3
# Class index: 1548, Frequency: 38
# Hold id and Val: 1511, 0
# Class index: 624, Frequency: 38
# Hold id and Val: 1229, 0
# Class index: 1110, Frequency: 38
# Hold id and Val: 1350, 2
# Class index: 780, Frequency: 38
# Hold id and Val: 1268, 0
# Class index: 1496, Frequency: 38
# Hold id and Val: 1498, 0
# Class index: 128, Frequency: 38
# Hold id and Val: 1105, 0
# Class index: 775, Frequency: 38
# Hold id and Val: 1266, 3
# Class index: 1480, Frequency: 37
# Hold id and Val: 1494, 0
# Class index: 1106, Frequency: 37
# Hold id and Val: 1349, 2
# Class index: 84, Frequency: 37
# Hold id and Val: 1094, 0
# Class index: 943, Frequency: 36
# Hold id and Val: 1308, 3
# ...
# Hold id and Val: 1258, 3
# Class index: 454, Frequency: 3
# Hold id and Val: 1186, 2
# Class index: 222, Frequency: 3
# Hold id and Val: 1128, 2
# Class index: 1421, Frequency: 3
# Hold id and Val: 1479, 1
# Class index: 1191, Frequency: 3
# Hold id and Val: 1370, 3
# Class index: 1722, Frequency: 3
# Hold id and Val: 1554, 2
# Class index: 1871, Frequency: 3
# Hold id and Val: 1591, 3
# Class index: 81, Frequency: 3
# Hold id and Val: 1093, 1
# Class index: 410, Frequency: 3
# Hold id and Val: 1175, 2
# Class index: 1441, Frequency: 3
# Hold id and Val: 1484, 1
# Class index: 269, Frequency: 3
# Hold id and Val: 1140, 1
# Class index: 346, Frequency: 3
# Hold id and Val: 1159, 2
# Class index: 944, Frequency: 3
# Hold id and Val: 1309, 0
# Class index: 566, Frequency: 3
# Hold id and Val: 1214, 2
# Class index: 1425, Frequency: 3
# Hold id and Val: 1480, 1
# Class index: 1349, Frequency: 3
# Hold id and Val: 1461, 1
# Class index: 766, Frequency: 3
# Hold id and Val: 1264, 2
# Class index: 1353, Frequency: 3
# Hold id and Val: 1462, 1
# Class index: 1263, Frequency: 3
# Hold id and Val: 1388, 3
# Class index: 1325, Frequency: 3
# Hold id and Val: 1455, 1
# Class index: 378, Frequency: 3
# Hold id and Val: 1167, 2
# Class index: 976, Frequency: 3
# Hold id and Val: 1317, 0
# Class index: 1477, Frequency: 3
# Hold id and Val: 1493, 1
# Class index: 1139, Frequency: 3
# Hold id and Val: 1357, 3
# Class index: 12, Frequency: 3
# Hold id and Val: 1076, 0
# Class index: 1373, Frequency: 3
# Hold id and Val: 1467, 1
# Class index: 310, Frequency: 2
# Hold id and Val: 1150, 2
# Class index: 1024, Frequency: 2
# Hold id and Val: 1329, 0
# Class index: 1814, Frequency: 2
# Hold id and Val: 1577, 2
# Class index: 1120, Frequency: 2
# Hold id and Val: 1353, 0
# Class index: 1678, Frequency: 2
# Hold id and Val: 1543, 2
# Class index: 254, Frequency: 2
# Hold id and Val: 1136, 2
# Class index: 904, Frequency: 2
# Hold id and Val: 1299, 0
# Class index: 900, Frequency: 2
# Hold id and Val: 1298, 0
# Class index: 258, Frequency: 2
# Hold id and Val: 1137, 2
# Class index: 1454, Frequency: 2
# Hold id and Val: 1487, 2
# Class index: 1902, Frequency: 2
# Hold id and Val: 1599, 2
# Class index: 150, Frequency: 2
# Hold id and Val: 1110, 2
# Class index: 880, Frequency: 2
# Hold id and Val: 1293, 0
# Class index: 129, Frequency: 2
# Hold id and Val: 1105, 1
# Class index: 1352, Frequency: 2
# Hold id and Val: 1462, 0
# Class index: 1453, Frequency: 2
# Hold id and Val: 1487, 1
# Class index: 0, Frequency: 2
# Hold id and Val: 1073, 0
# Class index: 38, Frequency: 2
# Hold id and Val: 1082, 2
# Class index: 1087, Frequency: 2
# Hold id and Val: 1344, 3
# Class index: 1670, Frequency: 2
# Hold id and Val: 1541, 2
# Class index: 137, Frequency: 2
# Hold id and Val: 1107, 1
# Class index: 1052, Frequency: 2
# Hold id and Val: 1336, 0
# Class index: 1236, Frequency: 2
# Hold id and Val: 1382, 0
# Class index: 1187, Frequency: 2
# Hold id and Val: 1369, 3
# Class index: 1688, Frequency: 2
# Hold id and Val: 1546, 0
# Class index: 1361, Frequency: 2
# Hold id and Val: 1464, 1
# Class index: 1473, Frequency: 2
# Hold id and Val: 1492, 1
# Class index: 1573, Frequency: 2
# Hold id and Val: 1517, 1
# Class index: 928, Frequency: 2
# Hold id and Val: 1305, 0
# Class index: 1550, Frequency: 2
# Hold id and Val: 1511, 2
# Class index: 1248, Frequency: 2
# Hold id and Val: 1385, 0
# Class index: 1264, Frequency: 2
# Hold id and Val: 1389, 0
# Class index: 1111, Frequency: 2
# Hold id and Val: 1350, 3
# Class index: 1838, Frequency: 2
# Hold id and Val: 1583, 2
# Class index: 1766, Frequency: 2
# Hold id and Val: 1565, 2
# Class index: 1219, Frequency: 2
# Hold id and Val: 1377, 3
# Class index: 1862, Frequency: 2
# Hold id and Val: 1589, 2
# Class index: 1429, Frequency: 2
# Hold id and Val: 1481, 1
# Class index: 1317, Frequency: 2
# Hold id and Val: 1453, 1
# Class index: 1301, Frequency: 2
# Hold id and Val: 1449, 1
# Class index: 538, Frequency: 2
# Hold id and Val: 1207, 2
# Class index: 626, Frequency: 2
# Hold id and Val: 1229, 2
# Class index: 1268, Frequency: 2
# Hold id and Val: 1390, 0
# Class index: 1340, Frequency: 2
# Hold id and Val: 1459, 0
# Class index: 1501, Frequency: 2
# Hold id and Val: 1499, 1
# Class index: 1728, Frequency: 2
# Hold id and Val: 1556, 0
# Class index: 506, Frequency: 2
# Hold id and Val: 1199, 2
# Class index: 262, Frequency: 2
# Hold id and Val: 1138, 2
# Class index: 286, Frequency: 2
# Hold id and Val: 1144, 2
# Class index: 984, Frequency: 2
# Hold id and Val: 1319, 0
# Class index: 1004, Frequency: 2
# Hold id and Val: 1324, 0
# Class index: 1195, Frequency: 2
# Hold id and Val: 1371, 3
# Class index: 1822, Frequency: 2
# Hold id and Val: 1579, 2
# Class index: 1283, Frequency: 2
# Hold id and Val: 1393, 3
# Class index: 1652, Frequency: 2
# Hold id and Val: 1537, 0
# Class index: 1068, Frequency: 2
# Hold id and Val: 1340, 0
# Class index: 1272, Frequency: 2
# Hold id and Val: 1391, 0
# Class index: 422, Frequency: 2
# Hold id and Val: 1178, 2
# Class index: 1761, Frequency: 2
# Hold id and Val: 1564, 1
# Class index: 1830, Frequency: 2
# Hold id and Val: 1581, 2
# Class index: 590, Frequency: 2
# Hold id and Val: 1220, 2
# Class index: 1235, Frequency: 2
# Hold id and Val: 1381, 3
# Class index: 1762, Frequency: 2
# Hold id and Val: 1564, 2
# Class index: 1465, Frequency: 2
# Hold id and Val: 1490, 1
# Class index: 318, Frequency: 2
# Hold id and Val: 1152, 2
# Class index: 1846, Frequency: 2
# Hold id and Val: 1585, 2
# Class index: 298, Frequency: 2
# Hold id and Val: 1147, 2
# Class index: 178, Frequency: 2
# Hold id and Val: 1117, 2
# Class index: 1156, Frequency: 2
# Hold id and Val: 1362, 0
# Class index: 1160, Frequency: 2
# Hold id and Val: 1363, 0
# Class index: 1850, Frequency: 2
# Hold id and Val: 1586, 2
# Class index: 1786, Frequency: 2
# Hold id and Val: 1570, 2
# Class index: 1617, Frequency: 2
# Hold id and Val: 1528, 1
# Class index: 1686, Frequency: 2
# Hold id and Val: 1545, 2
# Class index: 1015, Frequency: 2
# Hold id and Val: 1326, 3
# Class index: 498, Frequency: 2
# Hold id and Val: 1197, 2
# Class index: 1746, Frequency: 2
# Hold id and Val: 1560, 2
# Class index: 1341, Frequency: 2
# Hold id and Val: 1459, 1
# Class index: 414, Frequency: 2
# Hold id and Val: 1176, 2
# Class index: 470, Frequency: 2
# Hold id and Val: 1190, 2
# Class index: 302, Frequency: 2
# Hold id and Val: 1148, 2
# Class index: 1056, Frequency: 2
# Hold id and Val: 1337, 0
# Class index: 1608, Frequency: 2
# Hold id and Val: 1526, 0
# Class index: 16, Frequency: 2
# Hold id and Val: 1077, 0
# Class index: 206, Frequency: 2
# Hold id and Val: 1124, 2
# Class index: 1401, Frequency: 2
# Hold id and Val: 1474, 1
# Class index: 570, Frequency: 2
# Hold id and Val: 1215, 2
# Class index: 960, Frequency: 2
# Hold id and Val: 1313, 0
# Class index: 1019, Frequency: 2
# Hold id and Val: 1327, 3
# Class index: 20, Frequency: 2
# Hold id and Val: 1078, 0
# Class index: 246, Frequency: 2
# Hold id and Val: 1134, 2
# Class index: 968, Frequency: 2
# Hold id and Val: 1315, 0
# Class index: 394, Frequency: 2
# Hold id and Val: 1171, 2
# Class index: 1869, Frequency: 2
# Hold id and Val: 1591, 1
# Class index: 924, Frequency: 2
# Hold id and Val: 1304, 0
# Class index: 1095, Frequency: 2
# Hold id and Val: 1346, 3
# Class index: 972, Frequency: 2
# Hold id and Val: 1316, 0
# Class index: 1621, Frequency: 2
# Hold id and Val: 1529, 1
# Class index: 1345, Frequency: 2
# Hold id and Val: 1460, 1
# Class index: 1365, Frequency: 2
# Hold id and Val: 1465, 1
# Class index: 726, Frequency: 2
# Hold id and Val: 1254, 2
# Class index: 1400, Frequency: 2
# Hold id and Val: 1474, 0
# Class index: 1027, Frequency: 2
# Hold id and Val: 1329, 3
# Class index: 1369, Frequency: 2
# Hold id and Val: 1466, 1
# Class index: 1405, Frequency: 2
# Hold id and Val: 1475, 1
# Class index: 522, Frequency: 2
# Hold id and Val: 1203, 2
# Class index: 125, Frequency: 2
# Hold id and Val: 1104, 1
# Class index: 482, Frequency: 2
# Hold id and Val: 1193, 2
# Class index: 61, Frequency: 2
# Hold id and Val: 1088, 1
# Class index: 1798, Frequency: 2
# Hold id and Val: 1573, 2
# Class index: 1834, Frequency: 2
# Hold id and Val: 1582, 2
# Class index: 1802, Frequency: 2
# Hold id and Val: 1574, 2
# Class index: 390, Frequency: 2
# Hold id and Val: 1170, 2
# Class index: 1296, Frequency: 2
# Hold id and Val: 1448, 0
# Class index: 686, Frequency: 2
# Hold id and Val: 1244, 2
# Class index: 1155, Frequency: 2
# Hold id and Val: 1361, 3
# Class index: 1288, Frequency: 2
# Hold id and Val: 1395, 0
# Class index: 42, Frequency: 1
# Hold id and Val: 1083, 2
# Class index: 1240, Frequency: 1
# Hold id and Val: 1383, 0
# Class index: 1752, Frequency: 1
# Hold id and Val: 1562, 0
# Class index: 1103, Frequency: 1
# Hold id and Val: 1348, 3
# Class index: 230, Frequency: 1
# Hold id and Val: 1130, 2
# Class index: 166, Frequency: 1
# Hold id and Val: 1114, 2
# Class index: 1570, Frequency: 1
# Hold id and Val: 1516, 2
# Class index: 354, Frequency: 1
# Hold id and Val: 1161, 2
# Class index: 1135, Frequency: 1
# Hold id and Val: 1356, 3
# Class index: 218, Frequency: 1
# Hold id and Val: 1127, 2
# Class index: 154, Frequency: 1
# Hold id and Val: 1111, 2
# Class index: 1294, Frequency: 1
# Hold id and Val: 1447, 2
# Class index: 1204, Frequency: 1
# Hold id and Val: 1374, 0
# Class index: 1356, Frequency: 1
# Hold id and Val: 1463, 0
# Class index: 895, Frequency: 1
# Hold id and Val: 1296, 3
# Class index: 1744, Frequency: 1
# Hold id and Val: 1560, 0
# Class index: 1754, Frequency: 1
# Hold id and Val: 1562, 2
# Class index: 1706, Frequency: 1
# Hold id and Val: 1550, 2
# Class index: 1220, Frequency: 1
# Hold id and Val: 1378, 0
# Class index: 1216, Frequency: 1
# Hold id and Val: 1377, 0
# Class index: 1478, Frequency: 1
# Hold id and Val: 1493, 2
# Class index: 1690, Frequency: 1
# Hold id and Val: 1546, 2
# Class index: 1770, Frequency: 1
# Hold id and Val: 1566, 2
# Class index: 1734, Frequency: 1
# Hold id and Val: 1557, 2
# Class index: 1228, Frequency: 1
# Hold id and Val: 1380, 0
# Class index: 1032, Frequency: 1
# Hold id and Val: 1331, 0
# Class index: 1304, Frequency: 1
# Hold id and Val: 1450, 0
# Class index: 1446, Frequency: 1
# Hold id and Val: 1485, 2
# Class index: 1541, Frequency: 1
# Hold id and Val: 1509, 1
# Class index: 1790, Frequency: 1
# Hold id and Val: 1571, 2
# Class index: 1119, Frequency: 1
# Hold id and Val: 1352, 3
# Class index: 1406, Frequency: 1
# Hold id and Val: 1475, 2
# Class index: 1316, Frequency: 1
# Hold id and Val: 1453, 0
# Class index: 1788, Frequency: 1
# Hold id and Val: 1571, 0
# Class index: 1092, Frequency: 1
# Hold id and Val: 1346, 0
# Class index: 1748, Frequency: 1
# Hold id and Val: 1561, 0
# Class index: 270, Frequency: 1
# Hold id and Val: 1140, 2
# Class index: 118, Frequency: 1
# Hold id and Val: 1102, 2
# Class index: 1183, Frequency: 1
# Hold id and Val: 1368, 3
# Class index: 266, Frequency: 1
# Hold id and Val: 1139, 2
# Class index: 988, Frequency: 1
# Hold id and Val: 1320, 0
# Class index: 1666, Frequency: 1
# Hold id and Val: 1540, 2
# Class index: 1614, Frequency: 1
# Hold id and Val: 1527, 2
# Class index: 1630, Frequency: 1
# Hold id and Val: 1531, 2
# Class index: 1634, Frequency: 1
# Hold id and Val: 1532, 2
# Class index: 1534, Frequency: 1
# Hold id and Val: 1507, 2
# Class index: 662, Frequency: 1
# Hold id and Val: 1238, 2
# Class index: 1284, Frequency: 1
# Hold id and Val: 1394, 0
# Class index: 1662, Frequency: 1
# Hold id and Val: 1539, 2
# Class index: 193, Frequency: 1
# Hold id and Val: 1121, 1
# Class index: 1107, Frequency: 1
# Hold id and Val: 1349, 3
# Class index: 582, Frequency: 1
# Hold id and Val: 1218, 2
# Class index: 1736, Frequency: 1
# Hold id and Val: 1558, 0
# Class index: 1794, Frequency: 1
# Hold id and Val: 1572, 2
# Class index: 1860, Frequency: 1
# Hold id and Val: 1589, 0
# Class index: 146, Frequency: 1
# Hold id and Val: 1109, 2
# Class index: 1718, Frequency: 1
# Hold id and Val: 1553, 2
# Class index: 1901, Frequency: 1
# Hold id and Val: 1599, 1
# Class index: 1151, Frequency: 1
# Hold id and Val: 1360, 3
# Class index: 1620, Frequency: 1
# Hold id and Val: 1529, 0
# Class index: 1558, Frequency: 1
# Hold id and Val: 1513, 2
# Class index: 1638, Frequency: 1
# Hold id and Val: 1533, 2
# Class index: 1646, Frequency: 1
# Hold id and Val: 1535, 2
# Class index: 26, Frequency: 1
# Hold id and Val: 1079, 2
# Class index: 1852, Frequency: 1
# Hold id and Val: 1587, 0
# Class index: 1188, Frequency: 1
# Hold id and Val: 1370, 0
# Class index: 1115, Frequency: 1
# Hold id and Val: 1351, 3
# Class index: 1016, Frequency: 1
# Hold id and Val: 1327, 0
# Class index: 198, Frequency: 1
# Hold id and Val: 1122, 2
# Class index: 1060, Frequency: 1
# Hold id and Val: 1338, 0
# Class index: 598, Frequency: 1
# Hold id and Val: 1222, 2
# Class index: 967, Frequency: 1
# Hold id and Val: 1314, 3
# Class index: 1310, Frequency: 1
# Hold id and Val: 1451, 2
# Class index: 1308, Frequency: 1
# Hold id and Val: 1451, 0
# Class index: 1381, Frequency: 1
# Hold id and Val: 1469, 1
# Class index: 60, Frequency: 1
# Hold id and Val: 1088, 0
# Class index: 494, Frequency: 1
# Hold id and Val: 1196, 2
# Class index: 948, Frequency: 1
# Hold id and Val: 1310, 0
# Class index: 1502, Frequency: 1
# Hold id and Val: 1499, 2
# Class index: 1212, Frequency: 1
# Hold id and Val: 1376, 0
# Class index: 1562, Frequency: 1
# Hold id and Val: 1514, 2
# Class index: 1598, Frequency: 1
# Hold id and Val: 1523, 2
# Class index: 1626, Frequency: 1
# Hold id and Val: 1530, 2
# Class index: 1091, Frequency: 1
# Hold id and Val: 1345, 3
# Class index: 1714, Frequency: 1
# Hold id and Val: 1552, 2
# Class index: 326, Frequency: 1
# Hold id and Val: 1154, 2
# Class index: 1211, Frequency: 1
# Hold id and Val: 1375, 3
# Class index: 920, Frequency: 1
# Hold id and Val: 1303, 0
# Class index: 1302, Frequency: 1
# Hold id and Val: 1449, 2
# Class index: 1163, Frequency: 1
# Hold id and Val: 1363, 3
# Class index: 1445, Frequency: 1
# Hold id and Val: 1485, 1
# Class index: 754, Frequency: 1
# Hold id and Val: 1261, 2
# Class index: 1196, Frequency: 1
# Hold id and Val: 1372, 0
# Class index: 1208, Frequency: 1
# Hold id and Val: 1375, 0
# Class index: 1509, Frequency: 1
# Hold id and Val: 1501, 1
# Class index: 1072, Frequency: 1
# Hold id and Val: 1341, 0
# Class index: 1175, Frequency: 1
# Hold id and Val: 1366, 3
# Class index: 1382, Frequency: 1
# Hold id and Val: 1469, 2
# Class index: 398, Frequency: 1
# Hold id and Val: 1172, 2
# Class index: 162, Frequency: 1
# Hold id and Val: 1113, 2
# Class index: 66, Frequency: 1
# Hold id and Val: 1089, 2
# Class index: 201, Frequency: 1
# Hold id and Val: 1123, 1
# Class index: 1143, Frequency: 1
# Hold id and Val: 1358, 3
# Class index: 462, Frequency: 1
# Hold id and Val: 1188, 2
# Class index: 980, Frequency: 1
# Hold id and Val: 1318, 0
# Class index: 1730, Frequency: 1
# Hold id and Val: 1556, 2
# Class index: 1100, Frequency: 1
# Hold id and Val: 1348, 0
# Class index: 350, Frequency: 1
# Hold id and Val: 1160, 2
# Class index: 1884, Frequency: 1
# Hold id and Val: 1595, 0
# Class index: 992, Frequency: 1
# Hold id and Val: 1321, 0
# Class index: 1385, Frequency: 1
# Hold id and Val: 1470, 1
# Class index: 186, Frequency: 1
# Hold id and Val: 1119, 2
# Class index: 1048, Frequency: 1
# Hold id and Val: 1335, 0
# Class index: 1108, Frequency: 1
# Hold id and Val: 1350, 0
# Class index: 1602, Frequency: 1
# Hold id and Val: 1524, 2
# Class index: 1610, Frequency: 1
# Hold id and Val: 1526, 2
# Class index: 1247, Frequency: 1
# Hold id and Val: 1384, 3
# Class index: 94, Frequency: 1
# Hold id and Val: 1096, 2
# Class index: 1462, Frequency: 1
# Hold id and Val: 1489, 2
# Class index: 138, Frequency: 1
# Hold id and Val: 1107, 2
# Class index: 1720, Frequency: 1
# Hold id and Val: 1554, 0
# Class index: 1582, Frequency: 1
# Hold id and Val: 1519, 2
# Class index: 1498, Frequency: 1
# Hold id and Val: 1498, 2
# Class index: 1674, Frequency: 1
# Hold id and Val: 1542, 2
# Class index: 1854, Frequency: 1
# Hold id and Val: 1587, 2
# Class index: 8, Frequency: 1
# Hold id and Val: 1075, 0
# Class index: 142, Frequency: 1
# Hold id and Val: 1108, 2
# Class index: 490, Frequency: 1
# Hold id and Val: 1195, 2
# Class index: 85, Frequency: 1
# Hold id and Val: 1094, 1
# Class index: 1566, Frequency: 1
# Hold id and Val: 1515, 2
# Class index: 70, Frequency: 1
# Hold id and Val: 1090, 2
# Class index: 1422, Frequency: 1
# Hold id and Val: 1479, 2
# Class index: 514, Frequency: 1
# Hold id and Val: 1201, 2
# Class index: 1437, Frequency: 1
# Hold id and Val: 1483, 1
# Class index: 98, Frequency: 1
# Hold id and Val: 1097, 2
# Class index: 1088, Frequency: 1
# Hold id and Val: 1345, 0
# Class index: 1344, Frequency: 1
# Hold id and Val: 1460, 0
# Class index: 912, Frequency: 1
# Hold id and Val: 1301, 0
# Total sum of frequencies: 334254
# Total number of holds in the dataset: 2291091
# There is a discrepancy in the hold count.

# %%
total_instances = sum(len(batch[0]) for batch in DataLoader(train_dataset, batch_size=1, collate_fn=collate_fn))

# %%
print(len(dataset))
# Out:
# 40000

# %%
import matplotlib.pyplot as plt

# Assuming weight_tensor is your tensor containing class weights
plt.figure(figsize=(10, 6))
plt.bar(range(len(weight_tensor)), weight_tensor.cpu().numpy())
plt.xlabel('Class Index')
plt.ylabel('Weight')
plt.title('Class Weights')
plt.show()

# %% [markdown]
# ### Generate RNN Climb ###

# %%
def climb_to_tupleslist(row):
    frames = row['frames']

    triplets = frame_to_triplets(frames)
    hold_ids =  frame_to_ids(frames)[0]
    feature_tuples = []

    for i, (x, y, val) in enumerate(triplets):
        hold_direction, hold_quality = get_hold_vector(y, x)
        hold_class_id = id_to_class_id(hold_ids[i])
        val_class_id = val-2
        hold_val_class_id = ids_to_hold_val_class_id(hold_class_id, val_class_id)

        # Check if hold_direction is a list of lists and average if necessary
        if isinstance(hold_direction[0], list):  
            hold_direction = average_unit_vectors(hold_direction)

        hold_angle = unit_vector_to_cos(hold_direction)
        
        feature_tuple = (y, x, val- 2 , hold_class_id, hold_val_class_id, hold_angle, hold_quality)
        
        # Validate feature_tuple elements
        for j, feature in enumerate(feature_tuple):
            if not isinstance(feature, (int, float)):
                raise ValueError(f"Invalid feature type at index {j}: {type(feature)}")
        
        feature_tuples.append(feature_tuple)
    
    return feature_tuples



import random

def generate_climb(model, starting_hold_id, starting_val, num_holds):
    model.eval()
    
    # Initialize the starting tuple and convert to tensor
    starting_class_id = id_to_class_id(starting_hold_id)
    current_tuple = torch.tensor([hold_to_tuple(starting_class_id, starting_val)], dtype=torch.float).unsqueeze(0).to(device)

    generated_hold_ids = [starting_hold_id]
    generated_vals = [starting_val]

    # Initialize hidden states
    h0, c0 = None, None
    
    with torch.no_grad():
        for _ in range(num_holds - 1):
            lengths = torch.tensor([current_tuple.size(1)], dtype=torch.int64).to(device)

            hold_val_class_logits, h0, c0 = model(current_tuple, lengths, h0, c0)
            
            # Apply softmax to convert logits to probabilities
            hold_val_class_prob = F.softmax(hold_val_class_logits, dim=1)
            
            # hold_val_class_prob_cpu = hold_val_class_prob.squeeze().cpu().numpy()
            # plt.figure(figsize=(10, 6))
            # plt.bar(range(len(hold_val_class_prob_cpu)), hold_val_class_prob_cpu)
            # plt.xlabel('Hold Value Class ID')
            # plt.ylabel('Probability')
            # plt.title(f'Hold Value Class Probabilities at Step {_ + 1}')
            # plt.show()
            hold_val_class_id = torch.argmax(hold_val_class_prob, dim=1).item()
            # hold_val_top_indices = torch.topk(hold_val_class_prob, k=5, dim=1)[1].squeeze().tolist()
            # hold_val_class_id = random.choice(hold_val_top_indices)
            hold_class_id, val_class = hold_val_class_id_to_ids(hold_val_class_id)
            generated_hold_ids.append(class_id_to_id(hold_class_id))
            generated_vals.append(val_class)

            # Prepare the next input
            next_tuple = hold_to_tuple(hold_class_id, val_class)
            next_tensor = torch.tensor([next_tuple], dtype=torch.float).unsqueeze(0).to(device)
            
            # Concatenate next_tensor along the sequence dimension (dim=1)
            current_tuple = torch.cat((current_tuple, next_tensor), dim=1)
    
    return generated_hold_ids, generated_vals

def climb_to_imagecoords(hold_ids, vals):
    
    triplets = []
    
    for id_1, id_2 in zip(hold_ids, vals):
        if 1090 <= id_1 <= 1395: # big holds
            index  = id_1 - 1090
            origin = [45, 910]
            interDistance = 42
            x = origin[0] + ((index % 17) * interDistance) 
            y = origin[1] - ((index // 17) * interDistance)
        
        elif 1073 <= id_1 <= 1089: # bottom large feet
            index  = id_1 - 1073
            origin = [724, 955]
            interDistance = 42
            x = origin[0] - (index * interDistance) 
            y = origin[1] 
        
        elif 1447 <= id_1 <= 1464: # bottom small feet
            index  = id_1 - 1447
            origin = [744, 976]
            interDistance = 42
            x = origin[0] - (index * interDistance) 
            y = origin[1] 

        elif 1465 <= id_1 <= 1599: # small holds
            index  = id_1 - 1465
            if ((index //9) % 2) == 0:# if row is even
                origin = [18, 891]
                interDistance = 86
                x = origin[0] + ((index % 9) * interDistance) 
                y = origin[1] - (((index // 9)/2) * interDistance)
            else: # if row is odd
                origin = [64, 847]
                interDistance = 86  #86
                x = origin[0] + (((index % 9)) * interDistance) 
                y = origin[1] - ((((index // 9)-1) /2) * interDistance)
        
        else:
            # If id_1 does not fall into any of the specified ranges, skip or handle accordingly
            continue
        
        # Create the triplet (x, y, color) and append to the triplets list
        triplet = (x, y, id_2)
        triplets.append(triplet)
    
    return triplets

def draw_colored_circles_on_image(image_path, circles, save_as='KilterBoardSetup1.png'):
    hold_colors = {0: '#00FF00', 1: '#00FFFF', 2: '#FF00FF', 3: 'orange'}
    # green, cyan, magenta, orange
    image = Image.open(image_path)
    draw = ImageDraw.Draw(image)

    for x, y, z in circles:
        color = hold_colors.get(z, 'black')
        draw.ellipse((x - 7, y - 7, x + 7, y + 7), fill=color, outline=color)

    save_path = save_as
    image.save(save_path)

    saved_image = Image.open(save_path)
    fig, ax = plt.subplots(figsize=(6, 6)) 
    ax.imshow(saved_image)
    ax.axis('off')
    plt.title('Generated Climb')
    plt.show()

def climb_to_image(hold_ids, vals):
    image_path = "KilterBoardSetup.png"
    coords_list = climb_to_imagecoords(hold_ids, vals)
    draw_colored_circles_on_image(image_path, coords_list)

hold_ids, vals = generate_climb(model, 1081, 3, 12)
climb_to_image(hold_ids, vals)

# %%
print(hold_ids, vals)
# Out:
# [1081, 1395, 1395, 1395, 1395, 1395, 1395, 1395, 1395, 1395, 1395, 1395] [3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
# show(filtered_df)
print(torch.cuda.is_available())
# Out:
# True
